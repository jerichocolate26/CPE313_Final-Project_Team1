# %%
import shutil
import os

def clear_folder(folder_path):
    if os.path.exists(folder_path):
        for filename in os.listdir(folder_path):
            file_path = os.path.join(folder_path, filename)
            try:
                if os.path.isfile(file_path) or os.path.islink(file_path):
                    os.unlink(file_path)
                elif os.path.isdir(file_path):
                    shutil.rmtree(file_path)
            except Exception as e:
                print(f'Failed to delete {file_path}. Reason: {e}')
        print(f"All contents of the folder '{folder_path}' have been deleted successfully.")
    else:
        print(f"The folder '{folder_path}' does not exist.")

folder_path = '/content/frames'
clear_folder(folder_path)
# Out:
# The folder '/content/frames' has been deleted successfully.

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
model_path = '/content/drive/MyDrive/dogs_dataset/is_dog.pt' #YOLO Model
output_folder = '/content/dog_npy/' #For testing --ignore
frames_folder = '/content/frames/' #Just a temporary folder

#Better to use GDrive
root_folder = "/content/drive/MyDrive/dogs_dataset" #Dataset root path
new_root_folder = "/content/drive/MyDrive/train_dataset" #Storage of npy

batch_size = 12 #For LSTM Sequence
IMAGE_SIZE = (224, 224)
SEQUENCE_LENGTH = 12  # Number of frames per sequence
NUM_CLASSES = 5

# %%
# !pip install ultralytics
# Out:
# Collecting ultralytics
#   Downloading ultralytics-8.2.17-py3-none-any.whl (757 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 757.0/757.0 kB 7.7 MB/s eta 0:00:00
# Requirement already satisfied: matplotlib>=3.3.0 in /usr/local/lib/python3.10/dist-packages (from ultralytics) (3.7.1)
# Requirement already satisfied: opencv-python>=4.6.0 in /usr/local/lib/python3.10/dist-packages (from ultralytics) (4.8.0.76)
# Requirement already satisfied: pillow>=7.1.2 in /usr/local/lib/python3.10/dist-packages (from ultralytics) (9.4.0)
# Requirement already satisfied: pyyaml>=5.3.1 in /usr/local/lib/python3.10/dist-packages (from ultralytics) (6.0.1)
# Requirement already satisfied: requests>=2.23.0 in /usr/local/lib/python3.10/dist-packages (from ultralytics) (2.31.0)
# Requirement already satisfied: scipy>=1.4.1 in /usr/local/lib/python3.10/dist-packages (from ultralytics) (1.11.4)
# Requirement already satisfied: torch>=1.8.0 in /usr/local/lib/python3.10/dist-packages (from ultralytics) (2.2.1+cu121)
# Requirement already satisfied: torchvision>=0.9.0 in /usr/local/lib/python3.10/dist-packages (from ultralytics) (0.17.1+cu121)
# Requirement already satisfied: tqdm>=4.64.0 in /usr/local/lib/python3.10/dist-packages (from ultralytics) (4.66.4)
# Requirement already satisfied: psutil in /usr/local/lib/python3.10/dist-packages (from ultralytics) (5.9.5)
# Requirement already satisfied: py-cpuinfo in /usr/local/lib/python3.10/dist-packages (from ultralytics) (9.0.0)
# Collecting thop>=0.1.1 (from ultralytics)
#   Downloading thop-0.1.1.post2209072238-py3-none-any.whl (15 kB)
# Requirement already satisfied: pandas>=1.1.4 in /usr/local/lib/python3.10/dist-packages (from ultralytics) (2.0.3)
# Requirement already satisfied: seaborn>=0.11.0 in /usr/local/lib/python3.10/dist-packages (from ultralytics) (0.13.1)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.3.0->ultralytics) (1.2.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.3.0->ultralytics) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.3.0->ultralytics) (4.51.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.3.0->ultralytics) (1.4.5)
# Requirement already satisfied: numpy>=1.20 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.3.0->ultralytics) (1.25.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.3.0->ultralytics) (24.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.3.0->ultralytics) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.3.0->ultralytics) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.1.4->ultralytics) (2023.4)
# Requirement already satisfied: tzdata>=2022.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.1.4->ultralytics) (2024.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests>=2.23.0->ultralytics) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.23.0->ultralytics) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests>=2.23.0->ultralytics) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests>=2.23.0->ultralytics) (2024.2.2)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch>=1.8.0->ultralytics) (3.14.0)
# Requirement already satisfied: typing-extensions>=4.8.0 in /usr/local/lib/python3.10/dist-packages (from torch>=1.8.0->ultralytics) (4.11.0)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch>=1.8.0->ultralytics) (1.12)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=1.8.0->ultralytics) (3.3)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch>=1.8.0->ultralytics) (3.1.4)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from torch>=1.8.0->ultralytics) (2023.6.0)
# Collecting nvidia-cuda-nvrtc-cu12==12.1.105 (from torch>=1.8.0->ultralytics)
#   Using cached nvidia_cuda_nvrtc_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (23.7 MB)
# Collecting nvidia-cuda-runtime-cu12==12.1.105 (from torch>=1.8.0->ultralytics)
#   Using cached nvidia_cuda_runtime_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (823 kB)
# Collecting nvidia-cuda-cupti-cu12==12.1.105 (from torch>=1.8.0->ultralytics)
#   Using cached nvidia_cuda_cupti_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (14.1 MB)
# Collecting nvidia-cudnn-cu12==8.9.2.26 (from torch>=1.8.0->ultralytics)
#   Using cached nvidia_cudnn_cu12-8.9.2.26-py3-none-manylinux1_x86_64.whl (731.7 MB)
# Collecting nvidia-cublas-cu12==12.1.3.1 (from torch>=1.8.0->ultralytics)
#   Using cached nvidia_cublas_cu12-12.1.3.1-py3-none-manylinux1_x86_64.whl (410.6 MB)
# Collecting nvidia-cufft-cu12==11.0.2.54 (from torch>=1.8.0->ultralytics)
#   Using cached nvidia_cufft_cu12-11.0.2.54-py3-none-manylinux1_x86_64.whl (121.6 MB)
# Collecting nvidia-curand-cu12==10.3.2.106 (from torch>=1.8.0->ultralytics)
#   Using cached nvidia_curand_cu12-10.3.2.106-py3-none-manylinux1_x86_64.whl (56.5 MB)
# Collecting nvidia-cusolver-cu12==11.4.5.107 (from torch>=1.8.0->ultralytics)
#   Using cached nvidia_cusolver_cu12-11.4.5.107-py3-none-manylinux1_x86_64.whl (124.2 MB)
# Collecting nvidia-cusparse-cu12==12.1.0.106 (from torch>=1.8.0->ultralytics)
#   Using cached nvidia_cusparse_cu12-12.1.0.106-py3-none-manylinux1_x86_64.whl (196.0 MB)
# Collecting nvidia-nccl-cu12==2.19.3 (from torch>=1.8.0->ultralytics)
#   Using cached nvidia_nccl_cu12-2.19.3-py3-none-manylinux1_x86_64.whl (166.0 MB)
# Collecting nvidia-nvtx-cu12==12.1.105 (from torch>=1.8.0->ultralytics)
#   Using cached nvidia_nvtx_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (99 kB)
# Requirement already satisfied: triton==2.2.0 in /usr/local/lib/python3.10/dist-packages (from torch>=1.8.0->ultralytics) (2.2.0)
# Collecting nvidia-nvjitlink-cu12 (from nvidia-cusolver-cu12==11.4.5.107->torch>=1.8.0->ultralytics)
#   Using cached nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (21.1 MB)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.7->matplotlib>=3.3.0->ultralytics) (1.16.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch>=1.8.0->ultralytics) (2.1.5)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->torch>=1.8.0->ultralytics) (1.3.0)
# Installing collected packages: nvidia-nvtx-cu12, nvidia-nvjitlink-cu12, nvidia-nccl-cu12, nvidia-curand-cu12, nvidia-cufft-cu12, nvidia-cuda-runtime-cu12, nvidia-cuda-nvrtc-cu12, nvidia-cuda-cupti-cu12, nvidia-cublas-cu12, nvidia-cusparse-cu12, nvidia-cudnn-cu12, nvidia-cusolver-cu12, thop, ultralytics
# Successfully installed nvidia-cublas-cu12-12.1.3.1 nvidia-cuda-cupti-cu12-12.1.105 nvidia-cuda-nvrtc-cu12-12.1.105 nvidia-cuda-runtime-cu12-12.1.105 nvidia-cudnn-cu12-8.9.2.26 nvidia-cufft-cu12-11.0.2.54 nvidia-curand-cu12-10.3.2.106 nvidia-cusolver-cu12-11.4.5.107 nvidia-cusparse-cu12-12.1.0.106 nvidia-nccl-cu12-2.19.3 nvidia-nvjitlink-cu12-12.4.127 nvidia-nvtx-cu12-12.1.105 thop-0.1.1.post2209072238 ultralytics-8.2.17

# %%
from ultralytics import YOLO
from PIL import Image, ImageOps
import numpy as np
import matplotlib.pyplot as plt
import os
import cv2

model = YOLO(model_path)

# %%
def extract_frames(video_path, frames_folder):
    os.makedirs(frames_folder, exist_ok=True)
    cap = cv2.VideoCapture(video_path)
    frame_count = 0
    success = True

    # Extract the video base name without extension
    video_basename = os.path.splitext(os.path.basename(video_path))[0]

    while success:
        success, frame = cap.read()
        if success:
            frame_filename = os.path.join(frames_folder, f'frame_{frame_count:04d}.jpg')
            cv2.imwrite(frame_filename, frame)
            frame_count += 1

    cap.release()
    return frame_count

def detect_dog(img_path, output_folder, dog_frames, show=False):
    if img_path is not None:
        image = Image.open(img_path).convert('RGB')
        image_np = np.array(image)
        results = model(image_np, conf=0.25)
        os.makedirs(output_folder, exist_ok=True)
        detected_objects = results[0].boxes
        dog_count = 0

        for box in detected_objects:
            if box.cls == 0:  # Adjust this if 'dog' has a different class id
                x1, y1, x2, y2 = map(int, box.xyxy[0])
                cropped_image = image.crop((x1, y1, x2, y2))
                width, height = cropped_image.size
                max_dim = max(width, height)
                pad_left = (max_dim - width) // 2
                pad_top = (max_dim - height) // 2
                pad_right = max_dim - width - pad_left
                pad_bottom = max_dim - height - pad_top

                padded_image = ImageOps.expand(cropped_image, (pad_left, pad_top, pad_right, pad_bottom), fill=(0, 0, 0))
                resized_image = padded_image.resize((224, 224))

                dog_frames.append(np.array(resized_image))

                if show:
                  plt.imshow(resized_image)
                  plt.axis('off')
                  plt.show()

        dog_count = len(dog_frames)

        return dog_count

def frame_to_npy(video_path, frames_folder, output_folder, num_frames, show=False):
      dog_frames = []
      image_basename = os.path.splitext(os.path.basename(video_path))[0]

      for frame_number in range(num_frames):
          frame_path = os.path.join(frames_folder, f'frame_{frame_number:04d}.jpg')
          dog_num = detect_dog(frame_path, output_folder, dog_frames, show)

      np.save(os.path.join(output_folder, f'{image_basename}.npy'), np.array(dog_frames))

def batch_data(data, batch_size):
    """
    Batch the data based on the given batch size.

    Parameters:
    - data: numpy array, the data to be batched
    - batch_size: int, the size of each batch

    Returns:
    - batched_data: list of numpy arrays, where each array is a batch
    """
    num_samples = len(data)
    num_batches = num_samples // batch_size
    batched_data = []

    for i in range(num_batches):
        batch_start = i * batch_size
        batch_end = (i + 1) * batch_size
        batch = data[batch_start:batch_end]
        batched_data.append(batch)

    return np.array(batched_data)

# %%
'''#Get frame of a video
num_frames = extract_frames(video_path, frames_folder)
print(f"Extracted {num_frames} frames from the video.")
#Save to npy
frame_to_npy(video_path, frames_folder, output_folder, num_frames)
data = np.load('/content/dog_npy/Pitbull_barking_#shorts(360p).npy')
#Batch it for lstm
batch_size = 10
batched_data = batch_data(data, batch_size)
print("Number of batches:", len(batched_data))
print("Shape of first batch:", batched_data[0].shape)'''
# Out:
# '#Get frame of a video\nnum_frames = extract_frames(video_path, frames_folder)\nprint(f"Extracted {num_frames} frames from the video.")\n#Save to npy\nframe_to_npy(video_path, frames_folder, output_folder, num_frames)\ndata = np.load(\'/content/dog_npy/Pitbull_barking_#shorts(360p).npy\')\n#Batch it for lstm\nbatch_size = 10\nbatched_data = batch_data(data, batch_size)\nprint("Number of batches:", len(batched_data))\nprint("Shape of first batch:", batched_data[0].shape)'

# %%
def process_class_folder(class_folder, output_folder, batch_size):
    # Iterate over videos in class folder
    for video_file in os.listdir(class_folder):
        if video_file.endswith(".mp4"):
            video_path = os.path.join(class_folder, video_file)
            frames_folder = '/content/frames/'
            os.makedirs(frames_folder, exist_ok=True)
            num_frames = extract_frames(video_path, frames_folder)
            frame_to_npy(video_path, frames_folder, output_folder, num_frames)
            # Load processed data
            data = np.load(os.path.join(output_folder, f'{os.path.splitext(video_file)[0]}.npy'))
            # Batch data
            batched_data = batch_data(data, batch_size)
            # Save batched data
            np.save(os.path.join(output_folder, f'{os.path.splitext(video_file)[0]}_batched.npy'), batched_data)

def process_all_class_folders(root_folder, new_root_folder, batch_size):
    # Iterate over class folders
    for class_name in os.listdir(root_folder):
        class_folder = os.path.join(root_folder, class_name)
        if os.path.isdir(class_folder):
            output_class_folder = os.path.join(new_root_folder, class_name)
            os.makedirs(output_class_folder, exist_ok=True)
            process_class_folder(class_folder, output_class_folder, batch_size)

# %%
process_all_class_folders(root_folder, new_root_folder, batch_size)
# Out:
# Streaming output truncated to the last 5000 lines.
# 0: 384x640 2 0s, 8.7ms
# Speed: 1.8ms preprocess, 8.7ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 0s, 8.9ms
# Speed: 1.7ms preprocess, 8.9ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 0, 8.9ms
# Speed: 1.7ms preprocess, 8.9ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 0, 8.2ms
# Speed: 1.8ms preprocess, 8.2ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 0, 10.8ms
# Speed: 1.7ms preprocess, 10.8ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 0s, 8.9ms
# Speed: 2.1ms preprocess, 8.9ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 0s, 10.0ms
# Speed: 2.0ms preprocess, 10.0ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 0s, 9.8ms
# Speed: 1.8ms preprocess, 9.8ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 0, 9.3ms
# Speed: 1.7ms preprocess, 9.3ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 0, 9.1ms
# Speed: 1.7ms preprocess, 9.1ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 0, 8.6ms
# Speed: 1.8ms preprocess, 8.6ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 0, 9.4ms
# Speed: 1.7ms preprocess, 9.4ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 0s, 10.7ms
# Speed: 1.7ms preprocess, 10.7ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 0, 10.0ms
# Speed: 1.7ms preprocess, 10.0ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 0, 9.5ms
# Speed: 1.8ms preprocess, 9.5ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 0, 8.4ms
# Speed: 1.7ms preprocess, 8.4ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 0, 9.4ms
# Speed: 1.7ms preprocess, 9.4ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 0, 8.8ms
# Speed: 1.7ms preprocess, 8.8ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 0, 9.2ms
# Speed: 1.7ms preprocess, 9.2ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 0, 8.3ms
# Speed: 1.8ms preprocess, 8.3ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 0, 11.2ms
# Speed: 2.0ms preprocess, 11.2ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 0, 8.7ms
# Speed: 2.6ms preprocess, 8.7ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 0, 9.4ms
# Speed: 1.8ms preprocess, 9.4ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 0, 9.1ms
# Speed: 1.9ms preprocess, 9.1ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 0, 9.1ms
# Speed: 1.8ms preprocess, 9.1ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 0, 13.0ms
# Speed: 1.9ms preprocess, 13.0ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 0, 9.6ms
# Speed: 1.8ms preprocess, 9.6ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 0, 10.1ms
# Speed: 1.8ms preprocess, 10.1ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 0, 7.8ms
# Speed: 2.6ms preprocess, 7.8ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 0, 9.2ms
# Speed: 1.7ms preprocess, 9.2ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 0, 8.7ms
# Speed: 2.3ms preprocess, 8.7ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 0, 9.2ms
# Speed: 1.7ms preprocess, 9.2ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 0, 9.8ms
# Speed: 1.7ms preprocess, 9.8ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 0, 8.5ms
# Speed: 1.7ms preprocess, 8.5ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 0, 9.0ms
# Speed: 1.7ms preprocess, 9.0ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 0, 8.8ms
# Speed: 1.7ms preprocess, 8.8ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 0, 10.1ms
# Speed: 1.9ms preprocess, 10.1ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 0, 10.6ms
# Speed: 1.7ms preprocess, 10.6ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 0, 8.5ms
# Speed: 1.8ms preprocess, 8.5ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 0, 9.3ms
# Speed: 1.8ms preprocess, 9.3ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 0, 9.3ms
# Speed: 1.8ms preprocess, 9.3ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 0, 7.9ms
# Speed: 1.9ms preprocess, 7.9ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 0, 10.0ms
# Speed: 2.1ms preprocess, 10.0ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 0s, 8.9ms
# Speed: 2.0ms preprocess, 8.9ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 0, 15.3ms
# Speed: 2.1ms preprocess, 15.3ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 0, 8.0ms
# Speed: 1.7ms preprocess, 8.0ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 0, 8.8ms
# Speed: 1.6ms preprocess, 8.8ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 0, 9.2ms
# Speed: 2.6ms preprocess, 9.2ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 0s, 9.4ms
# Speed: 2.3ms preprocess, 9.4ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 0s, 9.2ms
# Speed: 2.1ms preprocess, 9.2ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 0, 11.5ms
# Speed: 2.2ms preprocess, 11.5ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 0s, 8.4ms
# Speed: 1.8ms preprocess, 8.4ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 0s, 8.7ms
# Speed: 1.7ms preprocess, 8.7ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 0s, 11.8ms
# Speed: 1.8ms preprocess, 11.8ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 0s, 9.7ms
# Speed: 2.0ms preprocess, 9.7ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 0s, 9.0ms
# Speed: 1.6ms preprocess, 9.0ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 0s, 9.6ms
# Speed: 1.9ms preprocess, 9.6ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 0, 10.9ms
# Speed: 1.6ms preprocess, 10.9ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 0s, 9.7ms
# Speed: 1.7ms preprocess, 9.7ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 0s, 10.3ms
# Speed: 1.7ms preprocess, 10.3ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 0s, 9.9ms
# Speed: 2.1ms preprocess, 9.9ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 0, 8.8ms
# Speed: 2.1ms preprocess, 8.8ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 0, 9.8ms
# Speed: 1.7ms preprocess, 9.8ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 0, 10.3ms
# Speed: 2.4ms preprocess, 10.3ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 0, 10.4ms
# Speed: 1.8ms preprocess, 10.4ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 0s, 8.8ms
# Speed: 1.7ms preprocess, 8.8ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 0, 9.3ms
# Speed: 1.8ms preprocess, 9.3ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 0s, 9.2ms
# Speed: 1.7ms preprocess, 9.2ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 0s, 9.8ms
# Speed: 2.2ms preprocess, 9.8ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 0s, 10.0ms
# Speed: 2.4ms preprocess, 10.0ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 0s, 9.1ms
# Speed: 2.3ms preprocess, 9.1ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 0s, 9.7ms
# Speed: 2.1ms preprocess, 9.7ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 0, 8.7ms
# Speed: 1.7ms preprocess, 8.7ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 0s, 9.7ms
# Speed: 2.1ms preprocess, 9.7ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 0s, 9.3ms
# Speed: 2.3ms preprocess, 9.3ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 0, 10.1ms
# Speed: 2.2ms preprocess, 10.1ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 0, 9.1ms
# Speed: 1.7ms preprocess, 9.1ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 0, 8.5ms
# Speed: 2.3ms preprocess, 8.5ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 0, 8.6ms
# Speed: 2.0ms preprocess, 8.6ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 0s, 9.6ms
# Speed: 7.6ms preprocess, 9.6ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 0, 11.0ms
# Speed: 1.7ms preprocess, 11.0ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 0, 8.3ms
# Speed: 1.9ms preprocess, 8.3ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 0, 10.5ms
# Speed: 1.7ms preprocess, 10.5ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 0s, 9.9ms
# Speed: 1.8ms preprocess, 9.9ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 0s, 9.6ms
# Speed: 1.7ms preprocess, 9.6ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 0s, 10.1ms
# Speed: 1.7ms preprocess, 10.1ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 0s, 9.9ms
# Speed: 2.3ms preprocess, 9.9ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 0s, 8.5ms
# Speed: 1.7ms preprocess, 8.5ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 0s, 10.1ms
# Speed: 1.8ms preprocess, 10.1ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 0s, 8.1ms
# Speed: 2.1ms preprocess, 8.1ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 0s, 9.7ms
# Speed: 1.7ms preprocess, 9.7ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 0s, 8.3ms
# Speed: 1.8ms preprocess, 8.3ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 0s, 8.8ms
# Speed: 2.0ms preprocess, 8.8ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 0s, 9.8ms
# Speed: 1.7ms preprocess, 9.8ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 0s, 9.5ms
# Speed: 2.3ms preprocess, 9.5ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 0s, 9.5ms
# Speed: 1.9ms preprocess, 9.5ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 0, 10.0ms
# Speed: 3.0ms preprocess, 10.0ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 0s, 9.1ms
# Speed: 1.6ms preprocess, 9.1ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 0s, 11.4ms
# Speed: 1.6ms preprocess, 11.4ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 0s, 8.6ms
# Speed: 1.7ms preprocess, 8.6ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 0s, 10.1ms
# Speed: 2.2ms preprocess, 10.1ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 0s, 9.6ms
# Speed: 1.8ms preprocess, 9.6ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 0s, 9.5ms
# Speed: 2.4ms preprocess, 9.5ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 0s, 9.6ms
# Speed: 1.8ms preprocess, 9.6ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 0s, 8.7ms
# Speed: 1.8ms preprocess, 8.7ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 0s, 10.6ms
# Speed: 2.4ms preprocess, 10.6ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 0s, 8.7ms
# Speed: 1.8ms preprocess, 8.7ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 0s, 10.3ms
# Speed: 2.0ms preprocess, 10.3ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 0s, 10.3ms
# Speed: 2.7ms preprocess, 10.3ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 0s, 8.8ms
# Speed: 1.8ms preprocess, 8.8ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 0s, 10.2ms
# Speed: 1.9ms preprocess, 10.2ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 0, 9.6ms
# Speed: 1.8ms preprocess, 9.6ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 0s, 8.8ms
# Speed: 1.7ms preprocess, 8.8ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 0s, 10.7ms
# Speed: 2.3ms preprocess, 10.7ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 0s, 9.9ms
# Speed: 2.5ms preprocess, 9.9ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 0, 9.5ms
# Speed: 1.7ms preprocess, 9.5ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 0s, 9.2ms
# Speed: 1.8ms preprocess, 9.2ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 0s, 10.2ms
# Speed: 2.4ms preprocess, 10.2ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 0s, 8.7ms
# Speed: 2.2ms preprocess, 8.7ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 0s, 12.6ms
# Speed: 1.8ms preprocess, 12.6ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 0s, 8.7ms
# Speed: 1.8ms preprocess, 8.7ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 0s, 9.7ms
# Speed: 1.8ms preprocess, 9.7ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 0s, 8.6ms
# Speed: 2.0ms preprocess, 8.6ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 0s, 9.6ms
# Speed: 1.8ms preprocess, 9.6ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 0s, 8.7ms
# Speed: 1.7ms preprocess, 8.7ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 0s, 9.4ms
# Speed: 1.8ms preprocess, 9.4ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 0s, 9.0ms
# Speed: 2.1ms preprocess, 9.0ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 0s, 12.9ms
# Speed: 1.8ms preprocess, 12.9ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 0s, 10.3ms
# Speed: 2.2ms preprocess, 10.3ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 0s, 12.2ms
# Speed: 2.0ms preprocess, 12.2ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 0s, 9.6ms
# Speed: 1.9ms preprocess, 9.6ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 0s, 9.7ms
# Speed: 2.0ms preprocess, 9.7ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 0s, 11.5ms
# Speed: 1.7ms preprocess, 11.5ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 0s, 8.2ms
# Speed: 3.1ms preprocess, 8.2ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 0s, 11.3ms
# Speed: 1.8ms preprocess, 11.3ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 0s, 9.3ms
# Speed: 2.7ms preprocess, 9.3ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 0s, 9.3ms
# Speed: 1.7ms preprocess, 9.3ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 0s, 8.6ms
# Speed: 1.8ms preprocess, 8.6ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 0s, 9.9ms
# Speed: 1.9ms preprocess, 9.9ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 0s, 11.9ms
# Speed: 2.5ms preprocess, 11.9ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 0s, 11.0ms
# Speed: 1.7ms preprocess, 11.0ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 0s, 10.4ms
# Speed: 1.7ms preprocess, 10.4ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 0s, 11.7ms
# Speed: 1.6ms preprocess, 11.7ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 0s, 9.1ms
# Speed: 2.0ms preprocess, 9.1ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 0s, 8.5ms
# Speed: 1.8ms preprocess, 8.5ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 0, 9.0ms
# Speed: 1.9ms preprocess, 9.0ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 0, 9.7ms
# Speed: 1.8ms preprocess, 9.7ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 0, 10.7ms
# Speed: 1.8ms preprocess, 10.7ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 0, 9.5ms
# Speed: 1.8ms preprocess, 9.5ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 0, 12.1ms
# Speed: 2.0ms preprocess, 12.1ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 0, 10.6ms
# Speed: 1.7ms preprocess, 10.6ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 0, 13.4ms
# Speed: 1.8ms preprocess, 13.4ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 0, 9.6ms
# Speed: 2.7ms preprocess, 9.6ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 0, 10.7ms
# Speed: 2.3ms preprocess, 10.7ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 0, 9.3ms
# Speed: 1.7ms preprocess, 9.3ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 0, 9.1ms
# Speed: 2.0ms preprocess, 9.1ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 0, 9.6ms
# Speed: 1.7ms preprocess, 9.6ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 0, 9.9ms
# Speed: 1.8ms preprocess, 9.9ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 0, 9.4ms
# Speed: 1.8ms preprocess, 9.4ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 0, 8.5ms
# Speed: 2.1ms preprocess, 8.5ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 0, 9.6ms
# Speed: 1.8ms preprocess, 9.6ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 0, 8.9ms
# Speed: 2.7ms preprocess, 8.9ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 0, 9.7ms
# Speed: 1.7ms preprocess, 9.7ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 0, 14.3ms
# Speed: 2.2ms preprocess, 14.3ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 0, 8.9ms
# Speed: 1.7ms preprocess, 8.9ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 0, 9.2ms
# Speed: 2.0ms preprocess, 9.2ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 0, 8.9ms
# Speed: 1.7ms preprocess, 8.9ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 0, 11.5ms
# Speed: 2.7ms preprocess, 11.5ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 0, 9.6ms
# Speed: 1.7ms preprocess, 9.6ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 0, 8.8ms
# Speed: 2.2ms preprocess, 8.8ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 0, 10.6ms
# Speed: 1.9ms preprocess, 10.6ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 0, 10.2ms
# Speed: 1.7ms preprocess, 10.2ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 0, 9.2ms
# Speed: 1.7ms preprocess, 9.2ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 0, 10.1ms
# Speed: 1.7ms preprocess, 10.1ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 0, 11.0ms
# Speed: 1.7ms preprocess, 11.0ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 0, 10.1ms
# Speed: 1.7ms preprocess, 10.1ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 0, 11.8ms
# Speed: 1.8ms preprocess, 11.8ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 0, 8.8ms
# Speed: 1.8ms preprocess, 8.8ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 0, 9.2ms
# Speed: 1.8ms preprocess, 9.2ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 0, 9.9ms
# Speed: 1.8ms preprocess, 9.9ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 0, 9.1ms
# Speed: 2.0ms preprocess, 9.1ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 0, 9.1ms
# Speed: 1.7ms preprocess, 9.1ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 0, 8.6ms
# Speed: 1.9ms preprocess, 8.6ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 0, 9.5ms
# Speed: 1.9ms preprocess, 9.5ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 0, 8.9ms
# Speed: 1.8ms preprocess, 8.9ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 0, 8.5ms
# Speed: 2.4ms preprocess, 8.5ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 0, 9.9ms
# Speed: 2.4ms preprocess, 9.9ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 0, 9.2ms
# Speed: 1.9ms preprocess, 9.2ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 0, 9.9ms
# Speed: 1.7ms preprocess, 9.9ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 0, 9.6ms
# Speed: 2.2ms preprocess, 9.6ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 0, 9.5ms
# Speed: 1.9ms preprocess, 9.5ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 0, 9.1ms
# Speed: 1.8ms preprocess, 9.1ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 0, 10.2ms
# Speed: 1.7ms preprocess, 10.2ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 0, 9.4ms
# Speed: 2.7ms preprocess, 9.4ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 0, 10.7ms
# Speed: 1.7ms preprocess, 10.7ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 0, 8.9ms
# Speed: 1.9ms preprocess, 8.9ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 0, 9.9ms
# Speed: 1.7ms preprocess, 9.9ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 0, 8.5ms
# Speed: 2.0ms preprocess, 8.5ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 0, 10.5ms
# Speed: 1.8ms preprocess, 10.5ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 0, 11.4ms
# Speed: 2.3ms preprocess, 11.4ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 0, 9.6ms
# Speed: 1.8ms preprocess, 9.6ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 0, 10.2ms
# Speed: 2.1ms preprocess, 10.2ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 0, 12.7ms
# Speed: 3.7ms preprocess, 12.7ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 0, 8.9ms
# Speed: 2.2ms preprocess, 8.9ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 0, 14.2ms
# Speed: 1.8ms preprocess, 14.2ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 0, 9.9ms
# Speed: 1.9ms preprocess, 9.9ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 0, 9.3ms
# Speed: 1.8ms preprocess, 9.3ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 0, 9.4ms
# Speed: 1.8ms preprocess, 9.4ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 0, 9.3ms
# Speed: 1.6ms preprocess, 9.3ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 0, 9.6ms
# Speed: 1.7ms preprocess, 9.6ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 0, 9.9ms
# Speed: 1.7ms preprocess, 9.9ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 0, 9.0ms
# Speed: 1.7ms preprocess, 9.0ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 0, 9.3ms
# Speed: 2.4ms preprocess, 9.3ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 0, 8.6ms
# Speed: 1.7ms preprocess, 8.6ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 0, 10.9ms
# Speed: 2.8ms preprocess, 10.9ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 0, 9.6ms
# Speed: 1.8ms preprocess, 9.6ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 0, 10.1ms
# Speed: 1.9ms preprocess, 10.1ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 0, 10.4ms
# Speed: 2.2ms preprocess, 10.4ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 0, 10.4ms
# Speed: 2.4ms preprocess, 10.4ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 0, 9.7ms
# Speed: 1.8ms preprocess, 9.7ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 0, 9.8ms
# Speed: 1.8ms preprocess, 9.8ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 0, 9.6ms
# Speed: 2.3ms preprocess, 9.6ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 0, 9.6ms
# Speed: 2.3ms preprocess, 9.6ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 11.2ms
# Speed: 2.0ms preprocess, 11.2ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 0, 10.2ms
# Speed: 1.9ms preprocess, 10.2ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 0, 8.8ms
# Speed: 1.8ms preprocess, 8.8ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 0, 8.5ms
# Speed: 1.8ms preprocess, 8.5ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 0, 10.3ms
# Speed: 2.0ms preprocess, 10.3ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 0, 8.7ms
# Speed: 1.8ms preprocess, 8.7ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 0, 13.0ms
# Speed: 2.0ms preprocess, 13.0ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 0, 10.9ms
# Speed: 1.8ms preprocess, 10.9ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 0, 10.3ms
# Speed: 1.8ms preprocess, 10.3ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 0, 8.8ms
# Speed: 2.4ms preprocess, 8.8ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 0, 9.8ms
# Speed: 2.1ms preprocess, 9.8ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 0, 9.0ms
# Speed: 1.8ms preprocess, 9.0ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 10.0ms
# Speed: 1.8ms preprocess, 10.0ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 8.8ms
# Speed: 2.5ms preprocess, 8.8ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 0, 12.9ms
# Speed: 1.8ms preprocess, 12.9ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 0, 10.3ms
# Speed: 2.3ms preprocess, 10.3ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 0, 9.7ms
# Speed: 2.2ms preprocess, 9.7ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 0, 9.4ms
# Speed: 2.0ms preprocess, 9.4ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 0, 9.3ms
# Speed: 1.7ms preprocess, 9.3ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 0, 12.9ms
# Speed: 2.4ms preprocess, 12.9ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 0, 8.2ms
# Speed: 2.5ms preprocess, 8.2ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 0, 9.9ms
# Speed: 1.8ms preprocess, 9.9ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 0, 9.6ms
# Speed: 2.1ms preprocess, 9.6ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 0, 14.6ms
# Speed: 1.8ms preprocess, 14.6ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 0, 12.9ms
# Speed: 1.8ms preprocess, 12.9ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 0, 10.5ms
# Speed: 3.0ms preprocess, 10.5ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 0, 11.6ms
# Speed: 1.7ms preprocess, 11.6ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 0, 14.4ms
# Speed: 2.5ms preprocess, 14.4ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 0, 13.6ms
# Speed: 1.9ms preprocess, 13.6ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 0, 10.3ms
# Speed: 1.7ms preprocess, 10.3ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 0, 14.1ms
# Speed: 4.6ms preprocess, 14.1ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 0, 17.6ms
# Speed: 1.6ms preprocess, 17.6ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 0, 13.9ms
# Speed: 1.8ms preprocess, 13.9ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 0, 12.8ms
# Speed: 1.8ms preprocess, 12.8ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 0, 12.6ms
# Speed: 1.9ms preprocess, 12.6ms inference, 2.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 0, 11.1ms
# Speed: 1.8ms preprocess, 11.1ms inference, 3.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 0, 10.3ms
# Speed: 1.7ms preprocess, 10.3ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 0, 10.1ms
# Speed: 1.7ms preprocess, 10.1ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 0, 10.9ms
# Speed: 1.7ms preprocess, 10.9ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 0, 10.1ms
# Speed: 1.7ms preprocess, 10.1ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 0, 10.2ms
# Speed: 1.9ms preprocess, 10.2ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 0, 19.7ms
# Speed: 2.1ms preprocess, 19.7ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 0, 12.2ms
# Speed: 2.1ms preprocess, 12.2ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 0, 13.6ms
# Speed: 2.0ms preprocess, 13.6ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 0, 11.8ms
# Speed: 1.9ms preprocess, 11.8ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 0, 9.6ms
# Speed: 1.9ms preprocess, 9.6ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 0, 17.2ms
# Speed: 1.7ms preprocess, 17.2ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 0, 11.5ms
# Speed: 1.7ms preprocess, 11.5ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 0, 15.4ms
# Speed: 1.7ms preprocess, 15.4ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 0, 9.2ms
# Speed: 3.5ms preprocess, 9.2ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 0, 10.3ms
# Speed: 3.4ms preprocess, 10.3ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 0, 10.2ms
# Speed: 1.6ms preprocess, 10.2ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 0, 9.9ms
# Speed: 1.8ms preprocess, 9.9ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 0, 13.5ms
# Speed: 5.4ms preprocess, 13.5ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 0, 10.0ms
# Speed: 1.8ms preprocess, 10.0ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 0, 10.4ms
# Speed: 3.1ms preprocess, 10.4ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 0, 11.7ms
# Speed: 1.6ms preprocess, 11.7ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 0, 9.5ms
# Speed: 3.2ms preprocess, 9.5ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 0, 8.9ms
# Speed: 3.3ms preprocess, 8.9ms inference, 3.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 0, 9.2ms
# Speed: 3.1ms preprocess, 9.2ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 0, 9.4ms
# Speed: 1.6ms preprocess, 9.4ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 0, 11.3ms
# Speed: 1.5ms preprocess, 11.3ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 0, 11.5ms
# Speed: 1.8ms preprocess, 11.5ms inference, 3.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 0, 10.8ms
# Speed: 1.5ms preprocess, 10.8ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 0, 11.0ms
# Speed: 1.6ms preprocess, 11.0ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 0, 10.3ms
# Speed: 1.7ms preprocess, 10.3ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 0, 9.7ms
# Speed: 3.0ms preprocess, 9.7ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 0, 13.2ms
# Speed: 3.2ms preprocess, 13.2ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 0, 10.5ms
# Speed: 2.0ms preprocess, 10.5ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 0, 14.8ms
# Speed: 3.9ms preprocess, 14.8ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 0, 13.4ms
# Speed: 1.7ms preprocess, 13.4ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 0, 16.3ms
# Speed: 1.8ms preprocess, 16.3ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 0, 16.9ms
# Speed: 1.7ms preprocess, 16.9ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 0, 14.9ms
# Speed: 1.8ms preprocess, 14.9ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 0, 12.9ms
# Speed: 2.0ms preprocess, 12.9ms inference, 3.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 0, 19.7ms
# Speed: 3.1ms preprocess, 19.7ms inference, 4.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 0, 13.8ms
# Speed: 1.8ms preprocess, 13.8ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 0, 10.7ms
# Speed: 1.7ms preprocess, 10.7ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 0, 10.8ms
# Speed: 1.8ms preprocess, 10.8ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 0, 10.8ms
# Speed: 1.7ms preprocess, 10.8ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 0, 14.2ms
# Speed: 1.7ms preprocess, 14.2ms inference, 5.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 0, 11.8ms
# Speed: 2.1ms preprocess, 11.8ms inference, 2.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 0, 12.8ms
# Speed: 1.9ms preprocess, 12.8ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 0, 10.4ms
# Speed: 1.6ms preprocess, 10.4ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 0, 9.5ms
# Speed: 2.0ms preprocess, 9.5ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 0, 10.2ms
# Speed: 1.8ms preprocess, 10.2ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 0, 10.8ms
# Speed: 1.7ms preprocess, 10.8ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 0, 10.1ms
# Speed: 1.7ms preprocess, 10.1ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 0, 10.4ms
# Speed: 1.6ms preprocess, 10.4ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 0s, 11.1ms
# Speed: 1.9ms preprocess, 11.1ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 0, 10.5ms
# Speed: 1.6ms preprocess, 10.5ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 0, 10.5ms
# Speed: 1.7ms preprocess, 10.5ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 0, 12.0ms
# Speed: 1.9ms preprocess, 12.0ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 0, 9.1ms
# Speed: 1.7ms preprocess, 9.1ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 0, 11.1ms
# Speed: 1.8ms preprocess, 11.1ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 0, 12.1ms
# Speed: 3.7ms preprocess, 12.1ms inference, 3.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 0s, 13.4ms
# Speed: 1.8ms preprocess, 13.4ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 0, 10.8ms
# Speed: 1.6ms preprocess, 10.8ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 0, 14.3ms
# Speed: 2.0ms preprocess, 14.3ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 0, 14.5ms
# Speed: 1.6ms preprocess, 14.5ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 0s, 10.2ms
# Speed: 1.8ms preprocess, 10.2ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 0, 10.4ms
# Speed: 1.6ms preprocess, 10.4ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 0, 9.5ms
# Speed: 1.9ms preprocess, 9.5ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 0, 9.8ms
# Speed: 1.7ms preprocess, 9.8ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 0, 9.2ms
# Speed: 1.9ms preprocess, 9.2ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 0, 15.4ms
# Speed: 1.6ms preprocess, 15.4ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 0, 10.3ms
# Speed: 1.5ms preprocess, 10.3ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 0s, 10.3ms
# Speed: 1.8ms preprocess, 10.3ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 0, 10.4ms
# Speed: 1.6ms preprocess, 10.4ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 0, 10.1ms
# Speed: 1.9ms preprocess, 10.1ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 0, 9.1ms
# Speed: 2.1ms preprocess, 9.1ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 0, 10.3ms
# Speed: 1.7ms preprocess, 10.3ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 0, 11.0ms
# Speed: 1.7ms preprocess, 11.0ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 0, 8.9ms
# Speed: 1.8ms preprocess, 8.9ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 0, 10.7ms
# Speed: 1.6ms preprocess, 10.7ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 0, 10.9ms
# Speed: 1.6ms preprocess, 10.9ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 0, 12.9ms
# Speed: 1.7ms preprocess, 12.9ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 0, 17.2ms
# Speed: 1.6ms preprocess, 17.2ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 0, 12.2ms
# Speed: 2.0ms preprocess, 12.2ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 0, 10.3ms
# Speed: 1.6ms preprocess, 10.3ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 0, 13.1ms
# Speed: 1.8ms preprocess, 13.1ms inference, 3.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 0, 13.3ms
# Speed: 2.0ms preprocess, 13.3ms inference, 6.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 0, 11.9ms
# Speed: 4.9ms preprocess, 11.9ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 0, 10.1ms
# Speed: 1.8ms preprocess, 10.1ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 0, 9.4ms
# Speed: 1.7ms preprocess, 9.4ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 0, 16.0ms
# Speed: 1.9ms preprocess, 16.0ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 0, 10.1ms
# Speed: 1.8ms preprocess, 10.1ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 0, 9.9ms
# Speed: 1.7ms preprocess, 9.9ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 0, 13.9ms
# Speed: 1.6ms preprocess, 13.9ms inference, 2.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 0, 12.8ms
# Speed: 1.9ms preprocess, 12.8ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 0, 17.6ms
# Speed: 1.8ms preprocess, 17.6ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 0, 20.0ms
# Speed: 2.0ms preprocess, 20.0ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 0, 14.7ms
# Speed: 1.7ms preprocess, 14.7ms inference, 14.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 0, 24.8ms
# Speed: 1.8ms preprocess, 24.8ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 0, 22.4ms
# Speed: 1.9ms preprocess, 22.4ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 0, 14.4ms
# Speed: 1.8ms preprocess, 14.4ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 0, 11.9ms
# Speed: 1.7ms preprocess, 11.9ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 0, 12.3ms
# Speed: 1.8ms preprocess, 12.3ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 0, 11.5ms
# Speed: 1.7ms preprocess, 11.5ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 0, 12.5ms
# Speed: 3.6ms preprocess, 12.5ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 0, 10.5ms
# Speed: 1.9ms preprocess, 10.5ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 0, 13.5ms
# Speed: 3.8ms preprocess, 13.5ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 0, 11.9ms
# Speed: 1.8ms preprocess, 11.9ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 0, 10.6ms
# Speed: 1.7ms preprocess, 10.6ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 0, 15.4ms
# Speed: 2.1ms preprocess, 15.4ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 0, 12.5ms
# Speed: 1.7ms preprocess, 12.5ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 0, 12.2ms
# Speed: 4.0ms preprocess, 12.2ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 0, 13.7ms
# Speed: 1.8ms preprocess, 13.7ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 0, 14.8ms
# Speed: 2.5ms preprocess, 14.8ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 0, 19.7ms
# Speed: 2.3ms preprocess, 19.7ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 0, 11.9ms
# Speed: 1.8ms preprocess, 11.9ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 0, 16.0ms
# Speed: 2.3ms preprocess, 16.0ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 0, 16.6ms
# Speed: 2.3ms preprocess, 16.6ms inference, 3.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 0, 16.1ms
# Speed: 1.8ms preprocess, 16.1ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 0, 13.9ms
# Speed: 2.9ms preprocess, 13.9ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 0, 19.1ms
# Speed: 2.1ms preprocess, 19.1ms inference, 2.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 0, 23.6ms
# Speed: 2.1ms preprocess, 23.6ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 0, 19.3ms
# Speed: 2.4ms preprocess, 19.3ms inference, 5.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 0, 15.1ms
# Speed: 2.0ms preprocess, 15.1ms inference, 4.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 0, 17.4ms
# Speed: 2.0ms preprocess, 17.4ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 0, 15.0ms
# Speed: 2.1ms preprocess, 15.0ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 0, 19.4ms
# Speed: 4.7ms preprocess, 19.4ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 0, 12.8ms
# Speed: 1.7ms preprocess, 12.8ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 0, 15.6ms
# Speed: 1.6ms preprocess, 15.6ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 0, 15.7ms
# Speed: 2.9ms preprocess, 15.7ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 0, 17.9ms
# Speed: 1.8ms preprocess, 17.9ms inference, 5.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 0, 8.5ms
# Speed: 2.3ms preprocess, 8.5ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 0, 8.5ms
# Speed: 1.9ms preprocess, 8.5ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 0, 9.7ms
# Speed: 2.2ms preprocess, 9.7ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 0, 9.7ms
# Speed: 1.8ms preprocess, 9.7ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 0, 9.7ms
# Speed: 1.7ms preprocess, 9.7ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 0, 9.5ms
# Speed: 2.2ms preprocess, 9.5ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 0, 11.6ms
# Speed: 1.7ms preprocess, 11.6ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 0, 9.9ms
# Speed: 1.9ms preprocess, 9.9ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 0, 9.8ms
# Speed: 1.7ms preprocess, 9.8ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 0, 10.1ms
# ...
# Speed: 1.8ms preprocess, 9.7ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 0, 9.2ms
# Speed: 2.0ms preprocess, 9.2ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 0, 9.7ms
# Speed: 1.9ms preprocess, 9.7ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 0, 9.2ms
# Speed: 2.9ms preprocess, 9.2ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 0, 10.5ms
# Speed: 3.1ms preprocess, 10.5ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 0, 9.3ms
# Speed: 2.8ms preprocess, 9.3ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 0, 9.0ms
# Speed: 2.0ms preprocess, 9.0ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 0, 9.6ms
# Speed: 2.6ms preprocess, 9.6ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 0, 8.6ms
# Speed: 1.8ms preprocess, 8.6ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 0, 12.6ms
# Speed: 1.7ms preprocess, 12.6ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 0, 13.0ms
# Speed: 1.8ms preprocess, 13.0ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 0, 11.5ms
# Speed: 1.8ms preprocess, 11.5ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 0, 10.1ms
# Speed: 2.0ms preprocess, 10.1ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 0, 10.9ms
# Speed: 1.9ms preprocess, 10.9ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 0, 9.8ms
# Speed: 2.1ms preprocess, 9.8ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 0, 10.3ms
# Speed: 2.3ms preprocess, 10.3ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 0, 9.9ms
# Speed: 2.2ms preprocess, 9.9ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 0, 10.5ms
# Speed: 2.0ms preprocess, 10.5ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 0, 10.0ms
# Speed: 1.9ms preprocess, 10.0ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 0, 9.6ms
# Speed: 2.0ms preprocess, 9.6ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 0, 8.6ms
# Speed: 2.8ms preprocess, 8.6ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 0, 9.6ms
# Speed: 2.1ms preprocess, 9.6ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 0, 9.6ms
# Speed: 1.8ms preprocess, 9.6ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 0, 10.4ms
# Speed: 1.8ms preprocess, 10.4ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 0, 10.6ms
# Speed: 1.8ms preprocess, 10.6ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 0, 8.9ms
# Speed: 1.9ms preprocess, 8.9ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 0, 9.5ms
# Speed: 3.0ms preprocess, 9.5ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 0, 8.7ms
# Speed: 1.8ms preprocess, 8.7ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 0, 9.0ms
# Speed: 2.4ms preprocess, 9.0ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 0, 13.0ms
# Speed: 2.4ms preprocess, 13.0ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 0, 13.4ms
# Speed: 2.9ms preprocess, 13.4ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 0, 13.1ms
# Speed: 1.8ms preprocess, 13.1ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 0, 12.9ms
# Speed: 1.8ms preprocess, 12.9ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 0, 16.1ms
# Speed: 1.9ms preprocess, 16.1ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 0, 15.6ms
# Speed: 2.8ms preprocess, 15.6ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 0, 15.1ms
# Speed: 2.9ms preprocess, 15.1ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 0, 11.7ms
# Speed: 1.8ms preprocess, 11.7ms inference, 2.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 0, 15.6ms
# Speed: 1.9ms preprocess, 15.6ms inference, 3.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 0, 14.4ms
# Speed: 1.9ms preprocess, 14.4ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 0, 10.7ms
# Speed: 1.7ms preprocess, 10.7ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 0, 15.7ms
# Speed: 3.9ms preprocess, 15.7ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 0, 10.5ms
# Speed: 2.0ms preprocess, 10.5ms inference, 6.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 0, 11.9ms
# Speed: 1.7ms preprocess, 11.9ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 0, 11.3ms
# Speed: 1.7ms preprocess, 11.3ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 0, 9.0ms
# Speed: 3.4ms preprocess, 9.0ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 0, 18.9ms
# Speed: 4.7ms preprocess, 18.9ms inference, 5.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 0, 14.8ms
# Speed: 3.0ms preprocess, 14.8ms inference, 2.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 0, 15.5ms
# Speed: 2.5ms preprocess, 15.5ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 0, 26.4ms
# Speed: 7.2ms preprocess, 26.4ms inference, 4.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 0, 22.0ms
# Speed: 3.1ms preprocess, 22.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 0, 15.4ms
# Speed: 1.6ms preprocess, 15.4ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 0, 14.6ms
# Speed: 3.6ms preprocess, 14.6ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 0, 17.9ms
# Speed: 3.1ms preprocess, 17.9ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 0, 27.6ms
# Speed: 3.6ms preprocess, 27.6ms inference, 6.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 0, 16.1ms
# Speed: 3.5ms preprocess, 16.1ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 0, 16.1ms
# Speed: 3.5ms preprocess, 16.1ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 0, 15.3ms
# Speed: 2.1ms preprocess, 15.3ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 0, 9.7ms
# Speed: 2.0ms preprocess, 9.7ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 0, 9.3ms
# Speed: 2.0ms preprocess, 9.3ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 0, 9.8ms
# Speed: 1.8ms preprocess, 9.8ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 0, 9.3ms
# Speed: 1.9ms preprocess, 9.3ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 0, 10.3ms
# Speed: 1.9ms preprocess, 10.3ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 0, 10.7ms
# Speed: 1.7ms preprocess, 10.7ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 0, 11.9ms
# Speed: 1.7ms preprocess, 11.9ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 0, 11.3ms
# Speed: 1.7ms preprocess, 11.3ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 0, 14.0ms
# Speed: 2.0ms preprocess, 14.0ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 0, 12.6ms
# Speed: 1.9ms preprocess, 12.6ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 0, 13.7ms
# Speed: 2.3ms preprocess, 13.7ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 0, 15.7ms
# Speed: 2.0ms preprocess, 15.7ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 0, 14.1ms
# Speed: 1.8ms preprocess, 14.1ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 0, 11.0ms
# Speed: 1.7ms preprocess, 11.0ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 0, 14.4ms
# Speed: 1.9ms preprocess, 14.4ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 0, 12.1ms
# Speed: 2.0ms preprocess, 12.1ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 0, 16.7ms
# Speed: 4.1ms preprocess, 16.7ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 0, 13.3ms
# Speed: 1.8ms preprocess, 13.3ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 0, 12.2ms
# Speed: 1.9ms preprocess, 12.2ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 0, 13.7ms
# Speed: 1.8ms preprocess, 13.7ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 0, 11.1ms
# Speed: 1.9ms preprocess, 11.1ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 0, 10.4ms
# Speed: 1.9ms preprocess, 10.4ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 0, 10.1ms
# Speed: 2.0ms preprocess, 10.1ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 0, 11.1ms
# Speed: 2.2ms preprocess, 11.1ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 0s, 9.7ms
# Speed: 2.2ms preprocess, 9.7ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 0s, 15.6ms
# Speed: 2.0ms preprocess, 15.6ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 0, 11.3ms
# Speed: 2.0ms preprocess, 11.3ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 0, 13.1ms
# Speed: 2.0ms preprocess, 13.1ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 0s, 13.7ms
# Speed: 2.4ms preprocess, 13.7ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 0s, 9.9ms
# Speed: 2.7ms preprocess, 9.9ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 0, 10.1ms
# Speed: 2.1ms preprocess, 10.1ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 0, 10.4ms
# Speed: 2.0ms preprocess, 10.4ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 0, 10.1ms
# Speed: 2.0ms preprocess, 10.1ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 0, 10.6ms
# Speed: 2.1ms preprocess, 10.6ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 0, 10.9ms
# Speed: 2.4ms preprocess, 10.9ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 0, 11.1ms
# Speed: 1.8ms preprocess, 11.1ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 0, 9.6ms
# Speed: 1.8ms preprocess, 9.6ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 0, 10.1ms
# Speed: 2.0ms preprocess, 10.1ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 0, 9.5ms
# Speed: 2.1ms preprocess, 9.5ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 0, 16.5ms
# Speed: 1.7ms preprocess, 16.5ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 0, 12.8ms
# Speed: 3.0ms preprocess, 12.8ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 0, 11.9ms
# Speed: 1.7ms preprocess, 11.9ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 0, 12.3ms
# Speed: 1.8ms preprocess, 12.3ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 0, 9.6ms
# Speed: 1.9ms preprocess, 9.6ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 0, 9.9ms
# Speed: 1.6ms preprocess, 9.9ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 0, 10.9ms
# Speed: 1.8ms preprocess, 10.9ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 0, 10.3ms
# Speed: 2.0ms preprocess, 10.3ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 0, 11.4ms
# Speed: 1.8ms preprocess, 11.4ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 0, 11.8ms
# Speed: 1.7ms preprocess, 11.8ms inference, 3.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 0, 9.4ms
# Speed: 1.7ms preprocess, 9.4ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 0, 10.2ms
# Speed: 1.7ms preprocess, 10.2ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 0, 9.6ms
# Speed: 1.8ms preprocess, 9.6ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 0, 10.4ms
# Speed: 1.8ms preprocess, 10.4ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 0, 9.5ms
# Speed: 2.3ms preprocess, 9.5ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 0, 10.5ms
# Speed: 1.6ms preprocess, 10.5ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 0, 10.9ms
# Speed: 1.9ms preprocess, 10.9ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 0, 9.8ms
# Speed: 1.6ms preprocess, 9.8ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 0, 9.6ms
# Speed: 1.6ms preprocess, 9.6ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 0, 11.3ms
# Speed: 1.7ms preprocess, 11.3ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 0, 9.5ms
# Speed: 1.7ms preprocess, 9.5ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 0, 9.8ms
# Speed: 1.6ms preprocess, 9.8ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 0, 8.7ms
# Speed: 1.8ms preprocess, 8.7ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 0, 10.5ms
# Speed: 1.9ms preprocess, 10.5ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 0, 9.4ms
# Speed: 1.8ms preprocess, 9.4ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 0, 9.8ms
# Speed: 1.7ms preprocess, 9.8ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 0, 10.4ms
# Speed: 1.8ms preprocess, 10.4ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 0, 14.7ms
# Speed: 1.8ms preprocess, 14.7ms inference, 3.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 0, 14.8ms
# Speed: 2.0ms preprocess, 14.8ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 0, 13.1ms
# Speed: 2.1ms preprocess, 13.1ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 0, 13.3ms
# Speed: 1.9ms preprocess, 13.3ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 0, 13.0ms
# Speed: 2.1ms preprocess, 13.0ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 0, 17.5ms
# Speed: 1.8ms preprocess, 17.5ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 0, 13.5ms
# Speed: 1.9ms preprocess, 13.5ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 0, 10.4ms
# Speed: 1.8ms preprocess, 10.4ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 0, 21.6ms
# Speed: 1.8ms preprocess, 21.6ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 0, 11.7ms
# Speed: 1.6ms preprocess, 11.7ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)

# %%
def load_npy_files(root_folder):
    npy_data = {}

    for class_name in os.listdir(root_folder):
        class_folder = os.path.join(root_folder, class_name)
        if os.path.isdir(class_folder):
            npy_data[class_name] = []
            for npy_file in os.listdir(class_folder):
                if npy_file.endswith(".npy"):
                    npy_path = os.path.join(class_folder, npy_file)
                    data = np.load(npy_path)
                    npy_data[class_name].append(data)
                    print(f"Loaded '{npy_file}' with shape: {data.shape}")

    return npy_data

npy_data = load_npy_files(root_folder)

# %% [markdown]
# #Loading for Training

# %%
import os
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder

# %%
def load_data(root_folder, label_encoder):
    X = []
    y = []
    class_dict = {}

    for idx, class_name in enumerate(os.listdir(root_folder)):
        class_folder = os.path.join(root_folder, class_name)
        if os.path.isdir(class_folder):
            class_dict[idx] = class_name
            for npy_file in os.listdir(class_folder):
                if npy_file.endswith(".npy"):
                    npy_path = os.path.join(class_folder, npy_file)
                    data = np.load(npy_path)
                    if data.shape[1:] == (12, 224, 224, 3):
                        X.extend(data)
                        y.extend([idx] * len(data))
                    else:
                        print(f"Skipping '{npy_file}' due to incorrect shape: {data.shape}")

    y_encoded = label_encoder.fit_transform(y)
    class_labels = {idx: class_name for idx, class_name in enumerate(label_encoder.classes_)}

    return np.array(X), y_encoded, class_dict, class_labels

label_encoder = LabelEncoder()

X, y_encoded, class_dict, class_labels = load_data(new_root_folder, label_encoder)

# Print the class dictionary
print("Class dictionary:")
print(class_dict)

# Print the class labels dictionary
print("Class labels dictionary:")
print(class_labels)
# Out:
# Skipping 'VID_20240501130111.npy' due to incorrect shape: (130, 224, 224, 3)
# Skipping 'Cutest Shih Tzu walk - 3 months old Mimi.npy' due to incorrect shape: (312, 224, 224, 3)
# Skipping 'VID_20240501130837.npy' due to incorrect shape: (98, 224, 224, 3)
# Skipping 'vlc-record-2024-05-18-12h52m00s-Train your dog to COME to you NO MATTER WHAT.mp4-.npy' due to incorrect shape: (203, 224, 224, 3)
# Skipping 'VID_20240501130158.npy' due to incorrect shape: (100, 224, 224, 3)
# Skipping 'vlc-record-2024-05-18-13h08m15s-The DOWN Command - Robert Cabral Dog Training #15.mp4-.npy' due to incorrect shape: (180, 224, 224, 3)
# Skipping 'vlc-record-2024-05-18-13h22m03s-Teach Your Dog To Go To Bed And RELAX - Professional Dog Training Tips.mp4-.npy' due to incorrect shape: (212, 224, 224, 3)
# Skipping 'vlc-record-2024-05-18-13h20m47s-Teach Your Dog To Go To Bed And RELAX - Professional Dog Training Tips.mp4-.npy' due to incorrect shape: (49, 224, 224, 3)
# Skipping 'vlc-record-2024-05-18-12h42m44s-Puppy Training Teach Your Puppy to Focus - Robert Cabral Dog Training Video.mp4-.npy' due to incorrect shape: (299, 224, 224, 3)
# Skipping 'vlc-record-2024-05-18-13h08m44s-The DOWN Command - Robert Cabral Dog Training #15.mp4-.npy' due to incorrect shape: (96, 224, 224, 3)
# Skipping 'vlc-record-2024-05-18-12h50m03s-Train your dog to COME to you NO MATTER WHAT.mp4-.npy' due to incorrect shape: (105, 224, 224, 3)
# Skipping 'vlc-record-2024-05-18-13h25m26s-Teach Your Dog to Sit.mp4-.npy' due to incorrect shape: (318, 224, 224, 3)
# Skipping 'shihtzu Dog Barking- ShihTzu barking #dogs #shihtzupuppies.npy' due to incorrect shape: (166, 224, 224, 3)
# Skipping 'Dog_barking_videos#4kviral#status#ytshorts(720p).npy' due to incorrect shape: (142, 224, 224, 3)
# Skipping 'Pitbull_barking_#shorts(360p).npy' due to incorrect shape: (136, 224, 224, 3)
# Skipping 'Big Dog Bark.npy' due to incorrect shape: (273, 224, 224, 3)
# Skipping 'VID_20240518135934.npy' due to incorrect shape: (96, 224, 224, 3)
# Skipping 'Labrador retriever barking 🐶🐾!#shorts.npy' due to incorrect shape: (452, 224, 224, 3)
# Skipping 'vlc-record-2024-05-18-13h41m07s-Barking Golden Retriever spots an airplane in the sky!.mp4-.npy' due to incorrect shape: (200, 224, 224, 3)
# Skipping 'VID_20240518135705.npy' due to incorrect shape: (131, 224, 224, 3)
# Skipping 'VID_20240518133023.npy' due to incorrect shape: (147, 224, 224, 3)
# Skipping 'VID_20240518131729.npy' due to incorrect shape: (105, 224, 224, 3)
# Skipping 'VID_20240518133528.npy' due to incorrect shape: (99, 224, 224, 3)
# Skipping 'VID_20240518131630.npy' due to incorrect shape: (101, 224, 224, 3)
# Skipping 'VID_20240518133646.npy' due to incorrect shape: (218, 224, 224, 3)
# Skipping 'VID_20240518140025.npy' due to incorrect shape: (81, 224, 224, 3)
# Skipping 'VID_20240518141033.npy' due to incorrect shape: (202, 224, 224, 3)
# Skipping 'vlc-record-2024-05-18-13h25m57s-Teach Your Dog to Sit.mp4-.npy' due to incorrect shape: (346, 224, 224, 3)
# Skipping 'Cute_tired_street_dog_sitting_at_the_beach_of_Alanya(720p).npy' due to incorrect shape: (1558, 224, 224, 3)
# Skipping 'vlc-record-2024-05-18-13h24m10s-Eames, correcting a sloppy- lazy sit stay..mp4-.npy' due to incorrect shape: (253, 224, 224, 3)
# Skipping 'Dog_sound__dog_barking__#shorts_#dogbarking_#viralshorts_#youtubeshorts_#dog_sound(720p).npy' due to incorrect shape: (123, 224, 224, 3)
# Skipping 'VID_20240501131125.npy' due to incorrect shape: (53, 224, 224, 3)
# Skipping 'vlc-record-2024-05-18-13h10m50s-Teach Your Dog to Look at You - with Stella - #13 Robert Cabral Dog Training.mp4-.npy' due to incorrect shape: (71, 224, 224, 3)
# Skipping 'vlc-record-2024-05-18-13h29m59s-Teach Your Dog to Come When Called.mp4-.npy' due to incorrect shape: (334, 224, 224, 3)
# Skipping 'vlc-record-2024-05-18-12h41m46s-Puppy Training Teach Your Puppy to Focus - Robert Cabral Dog Training Video.mp4-.npy' due to incorrect shape: (308, 224, 224, 3)
# Skipping 'vlc-record-2024-05-18-13h10m20s-Teach Your Dog to Look at You - with Stella - #13 Robert Cabral Dog Training.mp4-.npy' due to incorrect shape: (195, 224, 224, 3)
# Class dictionary:
# {0: 'walking', 1: 'lying', 2: 'barking', 3: 'sitting', 4: 'standing'}
# Class labels dictionary:
# {0: 0, 1: 1, 2: 2, 3: 3, 4: 4}

# %%
from keras.utils import to_categorical
y_one_hot = to_categorical(y_encoded)

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y_one_hot, test_size=0.3, random_state=42)

print("Training set shape:", X_train.shape, y_train.shape)
print("Testing set shape:", X_test.shape, y_test.shape)
# Out:
# Training set shape: (447, 12, 224, 224, 3) (447, 5)
# Testing set shape: (192, 12, 224, 224, 3) (192, 5)

# %% [markdown]
# # Training LSTM

# %% [markdown]
# ## Stacked LSTM

# %%
from tensorflow.keras.applications import InceptionV3
from tensorflow.keras.layers import Input, TimeDistributed, Flatten, LSTM, BatchNormalization, Dropout, Dense, Conv2D
from tensorflow.keras.models import Model
from tensorflow.keras.optimizers import Adam

# %%
base_model = InceptionV3(weights='imagenet', include_top=False, input_shape=(IMAGE_SIZE[0], IMAGE_SIZE[1], 3))
base_model.trainable = False

# Define LSTM model
inputs = Input(shape=(SEQUENCE_LENGTH,) + IMAGE_SIZE + (3,))
x = TimeDistributed(base_model)(inputs)
x = TimeDistributed(Flatten())(x)
x = LSTM(512, return_sequences=True)(x)  # First LSTM layer with return_sequences=True
x = LSTM(256, return_sequences=False)(x)  # Second LSTM layer with return_sequences=False
x = BatchNormalization()(x)
x = Dropout(0.5)(x)
outputs = Dense(NUM_CLASSES, activation='softmax')(x)
stack_model = Model(inputs, outputs)
opt = Adam(learning_rate=0.0001)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/inception_v3/inception_v3_weights_tf_dim_ordering_tf_kernels_notop.h5
# 87910968/87910968 [==============================] - 0s 0us/step

# %%
from keras.callbacks import ModelCheckpoint, EarlyStopping, ReduceLROnPlateau

stack_model.compile(loss='categorical_crossentropy', optimizer=opt, metrics=['accuracy'])
checkpoint_path = root_folder+'/best_stackmodel.h5'
checkpoint = ModelCheckpoint(checkpoint_path, monitor='val_accuracy', verbose=1, save_best_only=True, mode='max')
early_stopping = EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)
reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=1, min_lr=0.0000000001)

# Training
history_stack = stack_model.fit(X_train, y_train, epochs=100, batch_size=32, validation_data=(X_test, y_test), callbacks=[checkpoint, early_stopping, reduce_lr])
# Out:
# Epoch 1/100
# 14/14 [==============================] - ETA: 0s - loss: 1.4993 - accuracy: 0.5078
# Epoch 1: val_accuracy improved from -inf to 0.33333, saving model to /content/drive/MyDrive/dogs_dataset/best_stackmodel.h5
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# 14/14 [==============================] - 119s 6s/step - loss: 1.4993 - accuracy: 0.5078 - val_loss: 1.4064 - val_accuracy: 0.3333 - lr: 1.0000e-04
# Epoch 2/100
# 14/14 [==============================] - ETA: 0s - loss: 0.9585 - accuracy: 0.6667
# Epoch 2: val_accuracy improved from 0.33333 to 0.43229, saving model to /content/drive/MyDrive/dogs_dataset/best_stackmodel.h5
# 14/14 [==============================] - 31s 2s/step - loss: 0.9585 - accuracy: 0.6667 - val_loss: 1.3721 - val_accuracy: 0.4323 - lr: 1.0000e-04
# Epoch 3/100
# 14/14 [==============================] - ETA: 0s - loss: 0.6957 - accuracy: 0.7405
# Epoch 3: val_accuracy improved from 0.43229 to 0.59896, saving model to /content/drive/MyDrive/dogs_dataset/best_stackmodel.h5
# 14/14 [==============================] - 34s 3s/step - loss: 0.6957 - accuracy: 0.7405 - val_loss: 1.2670 - val_accuracy: 0.5990 - lr: 1.0000e-04
# Epoch 4/100
# 14/14 [==============================] - ETA: 0s - loss: 0.4596 - accuracy: 0.8456
# Epoch 4: val_accuracy improved from 0.59896 to 0.63021, saving model to /content/drive/MyDrive/dogs_dataset/best_stackmodel.h5
# 14/14 [==============================] - 34s 3s/step - loss: 0.4596 - accuracy: 0.8456 - val_loss: 1.2320 - val_accuracy: 0.6302 - lr: 1.0000e-04
# Epoch 5/100
# 14/14 [==============================] - ETA: 0s - loss: 0.4818 - accuracy: 0.8434
# Epoch 5: val_accuracy improved from 0.63021 to 0.67708, saving model to /content/drive/MyDrive/dogs_dataset/best_stackmodel.h5
# 14/14 [==============================] - 40s 3s/step - loss: 0.4818 - accuracy: 0.8434 - val_loss: 1.1958 - val_accuracy: 0.6771 - lr: 1.0000e-04
# Epoch 6/100
# 14/14 [==============================] - ETA: 0s - loss: 0.3218 - accuracy: 0.9016
# Epoch 6: val_accuracy improved from 0.67708 to 0.69792, saving model to /content/drive/MyDrive/dogs_dataset/best_stackmodel.h5
# 14/14 [==============================] - 36s 3s/step - loss: 0.3218 - accuracy: 0.9016 - val_loss: 1.1801 - val_accuracy: 0.6979 - lr: 1.0000e-04
# Epoch 7/100
# 14/14 [==============================] - ETA: 0s - loss: 0.3200 - accuracy: 0.8904
# Epoch 7: val_accuracy improved from 0.69792 to 0.70833, saving model to /content/drive/MyDrive/dogs_dataset/best_stackmodel.h5
# 14/14 [==============================] - 41s 3s/step - loss: 0.3200 - accuracy: 0.8904 - val_loss: 1.1253 - val_accuracy: 0.7083 - lr: 1.0000e-04
# Epoch 8/100
# 14/14 [==============================] - ETA: 0s - loss: 0.2383 - accuracy: 0.9239
# Epoch 8: val_accuracy did not improve from 0.70833
# 14/14 [==============================] - 19s 1s/step - loss: 0.2383 - accuracy: 0.9239 - val_loss: 1.0758 - val_accuracy: 0.6875 - lr: 1.0000e-04
# Epoch 9/100
# 14/14 [==============================] - ETA: 0s - loss: 0.2870 - accuracy: 0.9038
# Epoch 9: val_accuracy improved from 0.70833 to 0.71875, saving model to /content/drive/MyDrive/dogs_dataset/best_stackmodel.h5
# 14/14 [==============================] - 46s 3s/step - loss: 0.2870 - accuracy: 0.9038 - val_loss: 1.0749 - val_accuracy: 0.7188 - lr: 1.0000e-04
# Epoch 10/100
# 14/14 [==============================] - ETA: 0s - loss: 0.2580 - accuracy: 0.9239
# Epoch 10: val_accuracy did not improve from 0.71875
# 14/14 [==============================] - 17s 1s/step - loss: 0.2580 - accuracy: 0.9239 - val_loss: 1.1205 - val_accuracy: 0.6302 - lr: 1.0000e-04
# Epoch 11/100
# 14/14 [==============================] - ETA: 0s - loss: 0.2410 - accuracy: 0.9374
# Epoch 11: val_accuracy did not improve from 0.71875
# 14/14 [==============================] - 24s 2s/step - loss: 0.2410 - accuracy: 0.9374 - val_loss: 1.0442 - val_accuracy: 0.6823 - lr: 5.0000e-05
# Epoch 12/100
# 14/14 [==============================] - ETA: 0s - loss: 0.1972 - accuracy: 0.9441
# Epoch 12: val_accuracy improved from 0.71875 to 0.73958, saving model to /content/drive/MyDrive/dogs_dataset/best_stackmodel.h5
# 14/14 [==============================] - 45s 3s/step - loss: 0.1972 - accuracy: 0.9441 - val_loss: 0.9239 - val_accuracy: 0.7396 - lr: 5.0000e-05
# Epoch 13/100
# 14/14 [==============================] - ETA: 0s - loss: 0.1241 - accuracy: 0.9597
# Epoch 13: val_accuracy improved from 0.73958 to 0.76042, saving model to /content/drive/MyDrive/dogs_dataset/best_stackmodel.h5
# 14/14 [==============================] - 39s 3s/step - loss: 0.1241 - accuracy: 0.9597 - val_loss: 0.7897 - val_accuracy: 0.7604 - lr: 5.0000e-05
# Epoch 14/100
# 14/14 [==============================] - ETA: 0s - loss: 0.1116 - accuracy: 0.9709
# Epoch 14: val_accuracy improved from 0.76042 to 0.84896, saving model to /content/drive/MyDrive/dogs_dataset/best_stackmodel.h5
# 14/14 [==============================] - 41s 3s/step - loss: 0.1116 - accuracy: 0.9709 - val_loss: 0.7159 - val_accuracy: 0.8490 - lr: 5.0000e-05
# Epoch 15/100
# 14/14 [==============================] - ETA: 0s - loss: 0.0845 - accuracy: 0.9799
# Epoch 15: val_accuracy improved from 0.84896 to 0.89062, saving model to /content/drive/MyDrive/dogs_dataset/best_stackmodel.h5
# 14/14 [==============================] - 37s 3s/step - loss: 0.0845 - accuracy: 0.9799 - val_loss: 0.6995 - val_accuracy: 0.8906 - lr: 5.0000e-05
# Epoch 16/100
# 14/14 [==============================] - ETA: 0s - loss: 0.0723 - accuracy: 0.9799
# Epoch 16: val_accuracy improved from 0.89062 to 0.93750, saving model to /content/drive/MyDrive/dogs_dataset/best_stackmodel.h5
# 14/14 [==============================] - 32s 2s/step - loss: 0.0723 - accuracy: 0.9799 - val_loss: 0.6125 - val_accuracy: 0.9375 - lr: 5.0000e-05
# Epoch 17/100
# 14/14 [==============================] - ETA: 0s - loss: 0.0531 - accuracy: 0.9888
# Epoch 17: val_accuracy improved from 0.93750 to 0.95833, saving model to /content/drive/MyDrive/dogs_dataset/best_stackmodel.h5
# 14/14 [==============================] - 36s 3s/step - loss: 0.0531 - accuracy: 0.9888 - val_loss: 0.5648 - val_accuracy: 0.9583 - lr: 5.0000e-05
# Epoch 18/100
# 14/14 [==============================] - ETA: 0s - loss: 0.0433 - accuracy: 0.9978
# Epoch 18: val_accuracy did not improve from 0.95833
# 14/14 [==============================] - 24s 2s/step - loss: 0.0433 - accuracy: 0.9978 - val_loss: 0.4785 - val_accuracy: 0.9583 - lr: 5.0000e-05
# Epoch 19/100
# 14/14 [==============================] - ETA: 0s - loss: 0.0343 - accuracy: 0.9933
# Epoch 19: val_accuracy improved from 0.95833 to 0.97396, saving model to /content/drive/MyDrive/dogs_dataset/best_stackmodel.h5
# 14/14 [==============================] - 44s 3s/step - loss: 0.0343 - accuracy: 0.9933 - val_loss: 0.4181 - val_accuracy: 0.9740 - lr: 5.0000e-05
# Epoch 20/100
# 14/14 [==============================] - ETA: 0s - loss: 0.0432 - accuracy: 0.9843
# Epoch 20: val_accuracy did not improve from 0.97396
# 14/14 [==============================] - 19s 1s/step - loss: 0.0432 - accuracy: 0.9843 - val_loss: 0.3869 - val_accuracy: 0.9740 - lr: 5.0000e-05
# Epoch 21/100
# 14/14 [==============================] - ETA: 0s - loss: 0.0497 - accuracy: 0.9866
# Epoch 21: val_accuracy did not improve from 0.97396
# 14/14 [==============================] - 24s 2s/step - loss: 0.0497 - accuracy: 0.9866 - val_loss: 0.3268 - val_accuracy: 0.9375 - lr: 5.0000e-05
# Epoch 22/100
# 14/14 [==============================] - ETA: 0s - loss: 0.0372 - accuracy: 0.9978
# Epoch 22: val_accuracy did not improve from 0.97396
# 14/14 [==============================] - 18s 1s/step - loss: 0.0372 - accuracy: 0.9978 - val_loss: 0.2945 - val_accuracy: 0.9583 - lr: 5.0000e-05
# Epoch 23/100
# 14/14 [==============================] - ETA: 0s - loss: 0.0344 - accuracy: 0.9933
# Epoch 23: val_accuracy did not improve from 0.97396
# 14/14 [==============================] - 18s 1s/step - loss: 0.0344 - accuracy: 0.9933 - val_loss: 0.2507 - val_accuracy: 0.9635 - lr: 5.0000e-05
# Epoch 24/100
# 14/14 [==============================] - ETA: 0s - loss: 0.0386 - accuracy: 0.9955
# Epoch 24: val_accuracy did not improve from 0.97396
# 14/14 [==============================] - 18s 1s/step - loss: 0.0386 - accuracy: 0.9955 - val_loss: 0.2273 - val_accuracy: 0.9427 - lr: 5.0000e-05
# Epoch 25/100
# 14/14 [==============================] - ETA: 0s - loss: 0.0354 - accuracy: 0.9933
# Epoch 25: val_accuracy did not improve from 0.97396
# 14/14 [==============================] - 17s 1s/step - loss: 0.0354 - accuracy: 0.9933 - val_loss: 0.2331 - val_accuracy: 0.9375 - lr: 5.0000e-05
# Epoch 26/100
# 14/14 [==============================] - ETA: 0s - loss: 0.0224 - accuracy: 0.9955
# Epoch 26: val_accuracy did not improve from 0.97396
# 14/14 [==============================] - 18s 1s/step - loss: 0.0224 - accuracy: 0.9955 - val_loss: 0.2162 - val_accuracy: 0.9583 - lr: 2.5000e-05
# Epoch 27/100
# 14/14 [==============================] - ETA: 0s - loss: 0.0267 - accuracy: 0.9933
# Epoch 27: val_accuracy did not improve from 0.97396
# 14/14 [==============================] - 18s 1s/step - loss: 0.0267 - accuracy: 0.9933 - val_loss: 0.1847 - val_accuracy: 0.9583 - lr: 2.5000e-05
# Epoch 28/100
# 14/14 [==============================] - ETA: 0s - loss: 0.0144 - accuracy: 1.0000
# Epoch 28: val_accuracy did not improve from 0.97396
# 14/14 [==============================] - 18s 1s/step - loss: 0.0144 - accuracy: 1.0000 - val_loss: 0.1602 - val_accuracy: 0.9688 - lr: 2.5000e-05
# Epoch 29/100
# 14/14 [==============================] - ETA: 0s - loss: 0.0257 - accuracy: 0.9955
# Epoch 29: val_accuracy did not improve from 0.97396
# 14/14 [==============================] - 18s 1s/step - loss: 0.0257 - accuracy: 0.9955 - val_loss: 0.1386 - val_accuracy: 0.9688 - lr: 2.5000e-05
# Epoch 30/100
# 14/14 [==============================] - ETA: 0s - loss: 0.0211 - accuracy: 0.9978
# Epoch 30: val_accuracy did not improve from 0.97396
# 14/14 [==============================] - 18s 1s/step - loss: 0.0211 - accuracy: 0.9978 - val_loss: 0.1206 - val_accuracy: 0.9740 - lr: 2.5000e-05
# Epoch 31/100
# 14/14 [==============================] - ETA: 0s - loss: 0.0301 - accuracy: 0.9955
# Epoch 31: val_accuracy improved from 0.97396 to 0.97917, saving model to /content/drive/MyDrive/dogs_dataset/best_stackmodel.h5
# 14/14 [==============================] - 40s 3s/step - loss: 0.0301 - accuracy: 0.9955 - val_loss: 0.1149 - val_accuracy: 0.9792 - lr: 2.5000e-05
# Epoch 32/100
# 14/14 [==============================] - ETA: 0s - loss: 0.0168 - accuracy: 0.9978
# Epoch 32: val_accuracy did not improve from 0.97917
# 14/14 [==============================] - 24s 2s/step - loss: 0.0168 - accuracy: 0.9978 - val_loss: 0.1053 - val_accuracy: 0.9792 - lr: 2.5000e-05
# Epoch 33/100
# 14/14 [==============================] - ETA: 0s - loss: 0.0135 - accuracy: 0.9978
# Epoch 33: val_accuracy improved from 0.97917 to 0.98438, saving model to /content/drive/MyDrive/dogs_dataset/best_stackmodel.h5
# 14/14 [==============================] - 39s 3s/step - loss: 0.0135 - accuracy: 0.9978 - val_loss: 0.0994 - val_accuracy: 0.9844 - lr: 2.5000e-05
# Epoch 34/100
# 14/14 [==============================] - ETA: 0s - loss: 0.0168 - accuracy: 0.9955
# Epoch 34: val_accuracy did not improve from 0.98438
# 14/14 [==============================] - 19s 1s/step - loss: 0.0168 - accuracy: 0.9955 - val_loss: 0.0887 - val_accuracy: 0.9844 - lr: 2.5000e-05
# Epoch 35/100
# 14/14 [==============================] - ETA: 0s - loss: 0.0119 - accuracy: 1.0000
# Epoch 35: val_accuracy did not improve from 0.98438
# 14/14 [==============================] - 19s 1s/step - loss: 0.0119 - accuracy: 1.0000 - val_loss: 0.0767 - val_accuracy: 0.9844 - lr: 2.5000e-05
# Epoch 36/100
# 14/14 [==============================] - ETA: 0s - loss: 0.0119 - accuracy: 1.0000
# Epoch 36: val_accuracy did not improve from 0.98438
# 14/14 [==============================] - 18s 1s/step - loss: 0.0119 - accuracy: 1.0000 - val_loss: 0.0759 - val_accuracy: 0.9844 - lr: 2.5000e-05
# Epoch 37/100
# 14/14 [==============================] - ETA: 0s - loss: 0.0102 - accuracy: 1.0000
# Epoch 37: val_accuracy did not improve from 0.98438
# 14/14 [==============================] - 17s 1s/step - loss: 0.0102 - accuracy: 1.0000 - val_loss: 0.0764 - val_accuracy: 0.9792 - lr: 2.5000e-05
# Epoch 38/100
# 14/14 [==============================] - ETA: 0s - loss: 0.0122 - accuracy: 1.0000
# Epoch 38: val_accuracy did not improve from 0.98438
# 14/14 [==============================] - 18s 1s/step - loss: 0.0122 - accuracy: 1.0000 - val_loss: 0.0746 - val_accuracy: 0.9740 - lr: 1.2500e-05
# Epoch 39/100
# 14/14 [==============================] - ETA: 0s - loss: 0.0072 - accuracy: 1.0000
# Epoch 39: val_accuracy did not improve from 0.98438
# 14/14 [==============================] - 18s 1s/step - loss: 0.0072 - accuracy: 1.0000 - val_loss: 0.0732 - val_accuracy: 0.9792 - lr: 1.2500e-05
# Epoch 40/100
# 14/14 [==============================] - ETA: 0s - loss: 0.0137 - accuracy: 0.9955
# Epoch 40: val_accuracy did not improve from 0.98438
# 14/14 [==============================] - 18s 1s/step - loss: 0.0137 - accuracy: 0.9955 - val_loss: 0.0662 - val_accuracy: 0.9844 - lr: 1.2500e-05
# Epoch 41/100
# 14/14 [==============================] - ETA: 0s - loss: 0.0127 - accuracy: 0.9978
# Epoch 41: val_accuracy did not improve from 0.98438
# 14/14 [==============================] - 17s 1s/step - loss: 0.0127 - accuracy: 0.9978 - val_loss: 0.0704 - val_accuracy: 0.9844 - lr: 1.2500e-05
# Epoch 42/100
# 14/14 [==============================] - ETA: 0s - loss: 0.0145 - accuracy: 1.0000
# Epoch 42: val_accuracy did not improve from 0.98438
# 14/14 [==============================] - 17s 1s/step - loss: 0.0145 - accuracy: 1.0000 - val_loss: 0.0682 - val_accuracy: 0.9844 - lr: 6.2500e-06
# Epoch 43/100
# 14/14 [==============================] - ETA: 0s - loss: 0.0170 - accuracy: 0.9955
# Epoch 43: val_accuracy did not improve from 0.98438
# 14/14 [==============================] - 17s 1s/step - loss: 0.0170 - accuracy: 0.9955 - val_loss: 0.0663 - val_accuracy: 0.9844 - lr: 3.1250e-06
# Epoch 44/100
# 14/14 [==============================] - ETA: 0s - loss: 0.0150 - accuracy: 0.9978
# Epoch 44: val_accuracy did not improve from 0.98438
# 14/14 [==============================] - 18s 1s/step - loss: 0.0150 - accuracy: 0.9978 - val_loss: 0.0646 - val_accuracy: 0.9844 - lr: 1.5625e-06
# Epoch 45/100
# 14/14 [==============================] - ETA: 0s - loss: 0.0100 - accuracy: 1.0000
# Epoch 45: val_accuracy did not improve from 0.98438
# 14/14 [==============================] - 18s 1s/step - loss: 0.0100 - accuracy: 1.0000 - val_loss: 0.0634 - val_accuracy: 0.9844 - lr: 1.5625e-06
# Epoch 46/100
# 14/14 [==============================] - ETA: 0s - loss: 0.0125 - accuracy: 1.0000
# Epoch 46: val_accuracy did not improve from 0.98438
# 14/14 [==============================] - 18s 1s/step - loss: 0.0125 - accuracy: 1.0000 - val_loss: 0.0625 - val_accuracy: 0.9844 - lr: 1.5625e-06
# Epoch 47/100
# 14/14 [==============================] - ETA: 0s - loss: 0.0097 - accuracy: 1.0000
# Epoch 47: val_accuracy did not improve from 0.98438
# 14/14 [==============================] - 18s 1s/step - loss: 0.0097 - accuracy: 1.0000 - val_loss: 0.0619 - val_accuracy: 0.9844 - lr: 1.5625e-06
# Epoch 48/100
# 14/14 [==============================] - ETA: 0s - loss: 0.0088 - accuracy: 1.0000
# Epoch 48: val_accuracy did not improve from 0.98438
# 14/14 [==============================] - 18s 1s/step - loss: 0.0088 - accuracy: 1.0000 - val_loss: 0.0610 - val_accuracy: 0.9844 - lr: 1.5625e-06
# Epoch 49/100
# 14/14 [==============================] - ETA: 0s - loss: 0.0071 - accuracy: 1.0000
# Epoch 49: val_accuracy did not improve from 0.98438
# 14/14 [==============================] - 18s 1s/step - loss: 0.0071 - accuracy: 1.0000 - val_loss: 0.0603 - val_accuracy: 0.9844 - lr: 1.5625e-06
# Epoch 50/100
# 14/14 [==============================] - ETA: 0s - loss: 0.0127 - accuracy: 0.9978
# Epoch 50: val_accuracy did not improve from 0.98438
# 14/14 [==============================] - 18s 1s/step - loss: 0.0127 - accuracy: 0.9978 - val_loss: 0.0594 - val_accuracy: 0.9844 - lr: 1.5625e-06
# Epoch 51/100
# 14/14 [==============================] - ETA: 0s - loss: 0.0083 - accuracy: 1.0000
# Epoch 51: val_accuracy did not improve from 0.98438
# 14/14 [==============================] - 18s 1s/step - loss: 0.0083 - accuracy: 1.0000 - val_loss: 0.0574 - val_accuracy: 0.9844 - lr: 1.5625e-06
# Epoch 52/100
# 14/14 [==============================] - ETA: 0s - loss: 0.0081 - accuracy: 1.0000
# Epoch 52: val_accuracy did not improve from 0.98438
# 14/14 [==============================] - 18s 1s/step - loss: 0.0081 - accuracy: 1.0000 - val_loss: 0.0569 - val_accuracy: 0.9844 - lr: 1.5625e-06
# Epoch 53/100
# 14/14 [==============================] - ETA: 0s - loss: 0.0065 - accuracy: 1.0000
# Epoch 53: val_accuracy did not improve from 0.98438
# 14/14 [==============================] - 18s 1s/step - loss: 0.0065 - accuracy: 1.0000 - val_loss: 0.0566 - val_accuracy: 0.9844 - lr: 1.5625e-06
# Epoch 54/100
# 14/14 [==============================] - ETA: 0s - loss: 0.0134 - accuracy: 0.9978
# Epoch 54: val_accuracy did not improve from 0.98438
# 14/14 [==============================] - 18s 1s/step - loss: 0.0134 - accuracy: 0.9978 - val_loss: 0.0562 - val_accuracy: 0.9844 - lr: 1.5625e-06
# Epoch 55/100
# 14/14 [==============================] - ETA: 0s - loss: 0.0119 - accuracy: 0.9978
# Epoch 55: val_accuracy did not improve from 0.98438
# 14/14 [==============================] - 18s 1s/step - loss: 0.0119 - accuracy: 0.9978 - val_loss: 0.0557 - val_accuracy: 0.9844 - lr: 1.5625e-06
# Epoch 56/100
# 14/14 [==============================] - ETA: 0s - loss: 0.0080 - accuracy: 0.9978
# Epoch 56: val_accuracy did not improve from 0.98438
# 14/14 [==============================] - 18s 1s/step - loss: 0.0080 - accuracy: 0.9978 - val_loss: 0.0553 - val_accuracy: 0.9844 - lr: 1.5625e-06
# Epoch 57/100
# 14/14 [==============================] - ETA: 0s - loss: 0.0089 - accuracy: 1.0000
# Epoch 57: val_accuracy did not improve from 0.98438
# 14/14 [==============================] - 18s 1s/step - loss: 0.0089 - accuracy: 1.0000 - val_loss: 0.0551 - val_accuracy: 0.9844 - lr: 1.5625e-06
# Epoch 58/100
# 14/14 [==============================] - ETA: 0s - loss: 0.0104 - accuracy: 0.9978
# Epoch 58: val_accuracy did not improve from 0.98438
# 14/14 [==============================] - 18s 1s/step - loss: 0.0104 - accuracy: 0.9978 - val_loss: 0.0550 - val_accuracy: 0.9844 - lr: 1.5625e-06
# Epoch 59/100
# 14/14 [==============================] - ETA: 0s - loss: 0.0082 - accuracy: 1.0000
# Epoch 59: val_accuracy did not improve from 0.98438
# 14/14 [==============================] - 18s 1s/step - loss: 0.0082 - accuracy: 1.0000 - val_loss: 0.0545 - val_accuracy: 0.9844 - lr: 1.5625e-06
# Epoch 60/100
# 14/14 [==============================] - ETA: 0s - loss: 0.0101 - accuracy: 1.0000
# Epoch 60: val_accuracy did not improve from 0.98438
# 14/14 [==============================] - 18s 1s/step - loss: 0.0101 - accuracy: 1.0000 - val_loss: 0.0542 - val_accuracy: 0.9844 - lr: 1.5625e-06
# Epoch 61/100
# 14/14 [==============================] - ETA: 0s - loss: 0.0125 - accuracy: 1.0000
# Epoch 61: val_accuracy did not improve from 0.98438
# 14/14 [==============================] - 17s 1s/step - loss: 0.0125 - accuracy: 1.0000 - val_loss: 0.0548 - val_accuracy: 0.9844 - lr: 1.5625e-06
# Epoch 62/100
# 14/14 [==============================] - ETA: 0s - loss: 0.0070 - accuracy: 1.0000
# Epoch 62: val_accuracy did not improve from 0.98438
# 14/14 [==============================] - 17s 1s/step - loss: 0.0070 - accuracy: 1.0000 - val_loss: 0.0548 - val_accuracy: 0.9844 - lr: 7.8125e-07
# Epoch 63/100
# 14/14 [==============================] - ETA: 0s - loss: 0.0112 - accuracy: 0.9978
# Epoch 63: val_accuracy did not improve from 0.98438
# 14/14 [==============================] - 17s 1s/step - loss: 0.0112 - accuracy: 0.9978 - val_loss: 0.0548 - val_accuracy: 0.9844 - lr: 3.9062e-07
# Epoch 64/100
# 14/14 [==============================] - ETA: 0s - loss: 0.0124 - accuracy: 1.0000
# Epoch 64: val_accuracy did not improve from 0.98438
# 14/14 [==============================] - 17s 1s/step - loss: 0.0124 - accuracy: 1.0000 - val_loss: 0.0548 - val_accuracy: 0.9844 - lr: 1.9531e-07
# Epoch 65/100
# 14/14 [==============================] - ETA: 0s - loss: 0.0094 - accuracy: 0.9978
# Epoch 65: val_accuracy did not improve from 0.98438
# 14/14 [==============================] - 17s 1s/step - loss: 0.0094 - accuracy: 0.9978 - val_loss: 0.0548 - val_accuracy: 0.9844 - lr: 9.7656e-08
# Epoch 66/100
# 14/14 [==============================] - ETA: 0s - loss: 0.0118 - accuracy: 1.0000
# Epoch 66: val_accuracy did not improve from 0.98438
# 14/14 [==============================] - 17s 1s/step - loss: 0.0118 - accuracy: 1.0000 - val_loss: 0.0548 - val_accuracy: 0.9844 - lr: 4.8828e-08
# Epoch 67/100
# 14/14 [==============================] - ETA: 0s - loss: 0.0112 - accuracy: 0.9978
# Epoch 67: val_accuracy did not improve from 0.98438
# 14/14 [==============================] - 17s 1s/step - loss: 0.0112 - accuracy: 0.9978 - val_loss: 0.0549 - val_accuracy: 0.9844 - lr: 2.4414e-08
# Epoch 68/100
# 14/14 [==============================] - ETA: 0s - loss: 0.0131 - accuracy: 0.9978
# Epoch 68: val_accuracy did not improve from 0.98438
# 14/14 [==============================] - 17s 1s/step - loss: 0.0131 - accuracy: 0.9978 - val_loss: 0.0549 - val_accuracy: 0.9844 - lr: 1.2207e-08
# Epoch 69/100
# 14/14 [==============================] - ETA: 0s - loss: 0.0064 - accuracy: 1.0000
# Epoch 69: val_accuracy did not improve from 0.98438
# 14/14 [==============================] - 17s 1s/step - loss: 0.0064 - accuracy: 1.0000 - val_loss: 0.0549 - val_accuracy: 0.9844 - lr: 6.1035e-09
# Epoch 70/100
# 14/14 [==============================] - ETA: 0s - loss: 0.0087 - accuracy: 1.0000
# Epoch 70: val_accuracy did not improve from 0.98438
# 14/14 [==============================] - 18s 1s/step - loss: 0.0087 - accuracy: 1.0000 - val_loss: 0.0549 - val_accuracy: 0.9844 - lr: 3.0518e-09

# %% [markdown]
# ## Bidirectional LSTM

# %%
from tensorflow.keras.layers import Bidirectional

base_model = InceptionV3(weights='imagenet', include_top=False, input_shape=(IMAGE_SIZE[0], IMAGE_SIZE[1], 3))
base_model.trainable = False

# Define LSTM model
inputs = Input(shape=(SEQUENCE_LENGTH,) + IMAGE_SIZE + (3,))
x = TimeDistributed(base_model)(inputs)
x = TimeDistributed(Flatten())(x)
x = Bidirectional(LSTM(512, return_sequences=False))(x)  # Bidirectional LSTM layer
x = BatchNormalization()(x)
x = Dropout(0.5)(x)
outputs = Dense(NUM_CLASSES, activation='softmax')(x)
bi_model = Model(inputs, outputs)
opt = Adam(learning_rate=0.0001)
bi_model.compile(loss='categorical_crossentropy', optimizer=opt, metrics=['accuracy'])
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/inception_v3/inception_v3_weights_tf_dim_ordering_tf_kernels_notop.h5
# 87910968/87910968 [==============================] - 3s 0us/step

# %%
from keras.callbacks import ModelCheckpoint, EarlyStopping, ReduceLROnPlateau
# Define callbacks
checkpoint = ModelCheckpoint(root_folder+"/best_bimodel.h5", monitor='val_accuracy', verbose=1, save_best_only=True, mode='max')
early_stopping = EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)
reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=1, min_lr=0.0000000001)

# Training
history_bidirectional = bi_model.fit(X_train, y_train, epochs=100, batch_size=32, validation_data=(X_test, y_test), callbacks=[checkpoint, early_stopping, reduce_lr])
# Out:
# Epoch 1/100
# 14/14 [==============================] - ETA: 0s - loss: 1.3213 - accuracy: 0.5168
# Epoch 1: val_accuracy improved from -inf to 0.29688, saving model to /content/drive/MyDrive/dogs_dataset/best_bimodel.h5
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# 14/14 [==============================] - 132s 7s/step - loss: 1.3213 - accuracy: 0.5168 - val_loss: 1.8538 - val_accuracy: 0.2969 - lr: 1.0000e-04
# Epoch 2/100
# 14/14 [==============================] - ETA: 0s - loss: 0.8902 - accuracy: 0.7159
# Epoch 2: val_accuracy improved from 0.29688 to 0.30729, saving model to /content/drive/MyDrive/dogs_dataset/best_bimodel.h5
# 14/14 [==============================] - 50s 4s/step - loss: 0.8902 - accuracy: 0.7159 - val_loss: 1.7812 - val_accuracy: 0.3073 - lr: 1.0000e-04
# Epoch 3/100
# 14/14 [==============================] - ETA: 0s - loss: 0.8054 - accuracy: 0.7517
# Epoch 3: val_accuracy improved from 0.30729 to 0.31771, saving model to /content/drive/MyDrive/dogs_dataset/best_bimodel.h5
# 14/14 [==============================] - 79s 6s/step - loss: 0.8054 - accuracy: 0.7517 - val_loss: 1.7137 - val_accuracy: 0.3177 - lr: 1.0000e-04
# Epoch 4/100
# 14/14 [==============================] - ETA: 0s - loss: 0.7628 - accuracy: 0.8009
# Epoch 4: val_accuracy improved from 0.31771 to 0.33333, saving model to /content/drive/MyDrive/dogs_dataset/best_bimodel.h5
# 14/14 [==============================] - 63s 5s/step - loss: 0.7628 - accuracy: 0.8009 - val_loss: 1.6207 - val_accuracy: 0.3333 - lr: 1.0000e-04
# Epoch 5/100
# 14/14 [==============================] - ETA: 0s - loss: 0.7325 - accuracy: 0.8031
# Epoch 5: val_accuracy did not improve from 0.33333
# 14/14 [==============================] - 20s 1s/step - loss: 0.7325 - accuracy: 0.8031 - val_loss: 1.5206 - val_accuracy: 0.3021 - lr: 1.0000e-04
# Epoch 6/100
# 14/14 [==============================] - ETA: 0s - loss: 0.6800 - accuracy: 0.8322
# Epoch 6: val_accuracy did not improve from 0.33333
# 14/14 [==============================] - 21s 2s/step - loss: 0.6800 - accuracy: 0.8322 - val_loss: 1.4750 - val_accuracy: 0.3073 - lr: 1.0000e-04
# Epoch 7/100
# 14/14 [==============================] - ETA: 0s - loss: 0.7520 - accuracy: 0.7964
# Epoch 7: val_accuracy improved from 0.33333 to 0.36979, saving model to /content/drive/MyDrive/dogs_dataset/best_bimodel.h5
# 14/14 [==============================] - 70s 5s/step - loss: 0.7520 - accuracy: 0.7964 - val_loss: 1.4715 - val_accuracy: 0.3698 - lr: 1.0000e-04
# Epoch 8/100
# 14/14 [==============================] - ETA: 0s - loss: 0.7793 - accuracy: 0.8121
# Epoch 8: val_accuracy did not improve from 0.36979
# 14/14 [==============================] - 20s 1s/step - loss: 0.7793 - accuracy: 0.8121 - val_loss: 1.4501 - val_accuracy: 0.3333 - lr: 1.0000e-04
# Epoch 9/100
# 14/14 [==============================] - ETA: 0s - loss: 0.7357 - accuracy: 0.8188
# Epoch 9: val_accuracy improved from 0.36979 to 0.38542, saving model to /content/drive/MyDrive/dogs_dataset/best_bimodel.h5
# 14/14 [==============================] - 66s 5s/step - loss: 0.7357 - accuracy: 0.8188 - val_loss: 1.4572 - val_accuracy: 0.3854 - lr: 1.0000e-04
# Epoch 10/100
# 14/14 [==============================] - ETA: 0s - loss: 0.7401 - accuracy: 0.8233
# Epoch 10: val_accuracy improved from 0.38542 to 0.48438, saving model to /content/drive/MyDrive/dogs_dataset/best_bimodel.h5
# 14/14 [==============================] - 78s 6s/step - loss: 0.7401 - accuracy: 0.8233 - val_loss: 1.3398 - val_accuracy: 0.4844 - lr: 5.0000e-05
# Epoch 11/100
# 14/14 [==============================] - ETA: 0s - loss: 0.6676 - accuracy: 0.8546
# Epoch 11: val_accuracy improved from 0.48438 to 0.52083, saving model to /content/drive/MyDrive/dogs_dataset/best_bimodel.h5
# 14/14 [==============================] - 62s 5s/step - loss: 0.6676 - accuracy: 0.8546 - val_loss: 1.2593 - val_accuracy: 0.5208 - lr: 5.0000e-05
# Epoch 12/100
# 14/14 [==============================] - ETA: 0s - loss: 0.6608 - accuracy: 0.8546
# Epoch 12: val_accuracy improved from 0.52083 to 0.57292, saving model to /content/drive/MyDrive/dogs_dataset/best_bimodel.h5
# 14/14 [==============================] - 75s 6s/step - loss: 0.6608 - accuracy: 0.8546 - val_loss: 1.1740 - val_accuracy: 0.5729 - lr: 5.0000e-05
# Epoch 13/100
# 14/14 [==============================] - ETA: 0s - loss: 0.6316 - accuracy: 0.8546
# Epoch 13: val_accuracy improved from 0.57292 to 0.63021, saving model to /content/drive/MyDrive/dogs_dataset/best_bimodel.h5
# 14/14 [==============================] - 71s 5s/step - loss: 0.6316 - accuracy: 0.8546 - val_loss: 1.1233 - val_accuracy: 0.6302 - lr: 5.0000e-05
# Epoch 14/100
# 14/14 [==============================] - ETA: 0s - loss: 0.5855 - accuracy: 0.8859
# Epoch 14: val_accuracy improved from 0.63021 to 0.63542, saving model to /content/drive/MyDrive/dogs_dataset/best_bimodel.h5
# 14/14 [==============================] - 78s 6s/step - loss: 0.5855 - accuracy: 0.8859 - val_loss: 1.0902 - val_accuracy: 0.6354 - lr: 5.0000e-05
# Epoch 15/100
# 14/14 [==============================] - ETA: 0s - loss: 0.5825 - accuracy: 0.8881
# Epoch 15: val_accuracy improved from 0.63542 to 0.68229, saving model to /content/drive/MyDrive/dogs_dataset/best_bimodel.h5
# 14/14 [==============================] - 88s 7s/step - loss: 0.5825 - accuracy: 0.8881 - val_loss: 1.0518 - val_accuracy: 0.6823 - lr: 5.0000e-05
# Epoch 16/100
# 14/14 [==============================] - ETA: 0s - loss: 0.5750 - accuracy: 0.8814
# Epoch 16: val_accuracy improved from 0.68229 to 0.76042, saving model to /content/drive/MyDrive/dogs_dataset/best_bimodel.h5
# 14/14 [==============================] - 94s 7s/step - loss: 0.5750 - accuracy: 0.8814 - val_loss: 0.9688 - val_accuracy: 0.7604 - lr: 5.0000e-05
# Epoch 17/100
# 14/14 [==============================] - ETA: 0s - loss: 0.5627 - accuracy: 0.9016
# Epoch 17: val_accuracy improved from 0.76042 to 0.80208, saving model to /content/drive/MyDrive/dogs_dataset/best_bimodel.h5
# 14/14 [==============================] - 101s 8s/step - loss: 0.5627 - accuracy: 0.9016 - val_loss: 0.8869 - val_accuracy: 0.8021 - lr: 5.0000e-05
# Epoch 18/100
# 14/14 [==============================] - ETA: 0s - loss: 0.5558 - accuracy: 0.9083
# Epoch 18: val_accuracy did not improve from 0.80208
# 14/14 [==============================] - 17s 1s/step - loss: 0.5558 - accuracy: 0.9083 - val_loss: 0.8961 - val_accuracy: 0.8021 - lr: 5.0000e-05
# Epoch 19/100
# 14/14 [==============================] - ETA: 0s - loss: 0.5401 - accuracy: 0.8949
# Epoch 19: val_accuracy improved from 0.80208 to 0.81250, saving model to /content/drive/MyDrive/dogs_dataset/best_bimodel.h5
# 14/14 [==============================] - 77s 6s/step - loss: 0.5401 - accuracy: 0.8949 - val_loss: 0.8396 - val_accuracy: 0.8125 - lr: 2.5000e-05
# Epoch 20/100
# 14/14 [==============================] - ETA: 0s - loss: 0.5001 - accuracy: 0.9105
# Epoch 20: val_accuracy improved from 0.81250 to 0.82812, saving model to /content/drive/MyDrive/dogs_dataset/best_bimodel.h5
# 14/14 [==============================] - 105s 8s/step - loss: 0.5001 - accuracy: 0.9105 - val_loss: 0.7632 - val_accuracy: 0.8281 - lr: 2.5000e-05
# Epoch 21/100
# 14/14 [==============================] - ETA: 0s - loss: 0.4895 - accuracy: 0.8859
# Epoch 21: val_accuracy improved from 0.82812 to 0.86458, saving model to /content/drive/MyDrive/dogs_dataset/best_bimodel.h5
# 14/14 [==============================] - 77s 6s/step - loss: 0.4895 - accuracy: 0.8859 - val_loss: 0.7193 - val_accuracy: 0.8646 - lr: 2.5000e-05
# Epoch 22/100
# 14/14 [==============================] - ETA: 0s - loss: 0.4920 - accuracy: 0.9038
# Epoch 22: val_accuracy improved from 0.86458 to 0.87500, saving model to /content/drive/MyDrive/dogs_dataset/best_bimodel.h5
# 14/14 [==============================] - 91s 7s/step - loss: 0.4920 - accuracy: 0.9038 - val_loss: 0.6948 - val_accuracy: 0.8750 - lr: 2.5000e-05
# Epoch 23/100
# 14/14 [==============================] - ETA: 0s - loss: 0.4726 - accuracy: 0.9016
# Epoch 23: val_accuracy improved from 0.87500 to 0.90625, saving model to /content/drive/MyDrive/dogs_dataset/best_bimodel.h5
# 14/14 [==============================] - 93s 7s/step - loss: 0.4726 - accuracy: 0.9016 - val_loss: 0.6733 - val_accuracy: 0.9062 - lr: 2.5000e-05
# Epoch 24/100
# 14/14 [==============================] - ETA: 0s - loss: 0.4390 - accuracy: 0.9150
# Epoch 24: val_accuracy did not improve from 0.90625
# 14/14 [==============================] - 18s 1s/step - loss: 0.4390 - accuracy: 0.9150 - val_loss: 0.6502 - val_accuracy: 0.8958 - lr: 2.5000e-05
# Epoch 25/100
# 14/14 [==============================] - ETA: 0s - loss: 0.4624 - accuracy: 0.9060
# Epoch 25: val_accuracy did not improve from 0.90625
# 14/14 [==============================] - 20s 1s/step - loss: 0.4624 - accuracy: 0.9060 - val_loss: 0.6426 - val_accuracy: 0.8906 - lr: 2.5000e-05
# Epoch 26/100
# 14/14 [==============================] - ETA: 0s - loss: 0.4275 - accuracy: 0.9284
# Epoch 26: val_accuracy did not improve from 0.90625
# 14/14 [==============================] - 19s 1s/step - loss: 0.4275 - accuracy: 0.9284 - val_loss: 0.6017 - val_accuracy: 0.8958 - lr: 2.5000e-05
# Epoch 27/100
# 14/14 [==============================] - ETA: 0s - loss: 0.4286 - accuracy: 0.9217
# Epoch 27: val_accuracy did not improve from 0.90625
# 14/14 [==============================] - 18s 1s/step - loss: 0.4286 - accuracy: 0.9217 - val_loss: 0.5905 - val_accuracy: 0.8958 - lr: 2.5000e-05
# Epoch 28/100
# 14/14 [==============================] - ETA: 0s - loss: 0.4367 - accuracy: 0.9284
# Epoch 28: val_accuracy did not improve from 0.90625
# 14/14 [==============================] - 20s 1s/step - loss: 0.4367 - accuracy: 0.9284 - val_loss: 0.5520 - val_accuracy: 0.9062 - lr: 2.5000e-05
# Epoch 29/100
# 14/14 [==============================] - ETA: 0s - loss: 0.4018 - accuracy: 0.9374
# Epoch 29: val_accuracy did not improve from 0.90625
# 14/14 [==============================] - 19s 1s/step - loss: 0.4018 - accuracy: 0.9374 - val_loss: 0.5383 - val_accuracy: 0.8906 - lr: 2.5000e-05
# Epoch 30/100
# 14/14 [==============================] - ETA: 0s - loss: 0.4213 - accuracy: 0.9351
# Epoch 30: val_accuracy did not improve from 0.90625
# 14/14 [==============================] - 19s 1s/step - loss: 0.4213 - accuracy: 0.9351 - val_loss: 0.5045 - val_accuracy: 0.9062 - lr: 2.5000e-05
# Epoch 31/100
# 14/14 [==============================] - ETA: 0s - loss: 0.4087 - accuracy: 0.9284
# Epoch 31: val_accuracy improved from 0.90625 to 0.92708, saving model to /content/drive/MyDrive/dogs_dataset/best_bimodel.h5
# 14/14 [==============================] - 82s 6s/step - loss: 0.4087 - accuracy: 0.9284 - val_loss: 0.4860 - val_accuracy: 0.9271 - lr: 2.5000e-05
# Epoch 32/100
# 14/14 [==============================] - ETA: 0s - loss: 0.3983 - accuracy: 0.9418
# Epoch 32: val_accuracy did not improve from 0.92708
# 14/14 [==============================] - 18s 1s/step - loss: 0.3983 - accuracy: 0.9418 - val_loss: 0.4918 - val_accuracy: 0.9115 - lr: 2.5000e-05
# Epoch 33/100
# 14/14 [==============================] - ETA: 0s - loss: 0.3809 - accuracy: 0.9396
# Epoch 33: val_accuracy did not improve from 0.92708
# 14/14 [==============================] - 20s 1s/step - loss: 0.3809 - accuracy: 0.9396 - val_loss: 0.4804 - val_accuracy: 0.8958 - lr: 1.2500e-05
# Epoch 34/100
# 14/14 [==============================] - ETA: 0s - loss: 0.3998 - accuracy: 0.9284
# Epoch 34: val_accuracy did not improve from 0.92708
# 14/14 [==============================] - 20s 1s/step - loss: 0.3998 - accuracy: 0.9284 - val_loss: 0.4674 - val_accuracy: 0.9062 - lr: 1.2500e-05
# Epoch 35/100
# 14/14 [==============================] - ETA: 0s - loss: 0.3658 - accuracy: 0.9351
# Epoch 35: val_accuracy did not improve from 0.92708
# 14/14 [==============================] - 19s 1s/step - loss: 0.3658 - accuracy: 0.9351 - val_loss: 0.4645 - val_accuracy: 0.9010 - lr: 1.2500e-05
# Epoch 36/100
# 14/14 [==============================] - ETA: 0s - loss: 0.3666 - accuracy: 0.9396
# Epoch 36: val_accuracy did not improve from 0.92708
# 14/14 [==============================] - 20s 1s/step - loss: 0.3666 - accuracy: 0.9396 - val_loss: 0.4465 - val_accuracy: 0.9115 - lr: 1.2500e-05
# Epoch 37/100
# 14/14 [==============================] - ETA: 0s - loss: 0.3738 - accuracy: 0.9284
# Epoch 37: val_accuracy did not improve from 0.92708
# 14/14 [==============================] - 19s 1s/step - loss: 0.3738 - accuracy: 0.9284 - val_loss: 0.4440 - val_accuracy: 0.9219 - lr: 1.2500e-05
# Epoch 38/100
# 14/14 [==============================] - ETA: 0s - loss: 0.3506 - accuracy: 0.9463
# Epoch 38: val_accuracy did not improve from 0.92708
# 14/14 [==============================] - 19s 1s/step - loss: 0.3506 - accuracy: 0.9463 - val_loss: 0.4426 - val_accuracy: 0.9115 - lr: 1.2500e-05
# Epoch 39/100
# 14/14 [==============================] - ETA: 0s - loss: 0.3484 - accuracy: 0.9553
# Epoch 39: val_accuracy did not improve from 0.92708
# 14/14 [==============================] - 19s 1s/step - loss: 0.3484 - accuracy: 0.9553 - val_loss: 0.4314 - val_accuracy: 0.9010 - lr: 1.2500e-05
# Epoch 40/100
# 14/14 [==============================] - ETA: 0s - loss: 0.3687 - accuracy: 0.9329
# Epoch 40: val_accuracy did not improve from 0.92708
# 14/14 [==============================] - 19s 1s/step - loss: 0.3687 - accuracy: 0.9329 - val_loss: 0.4234 - val_accuracy: 0.9062 - lr: 1.2500e-05
# Epoch 41/100
# 14/14 [==============================] - ETA: 0s - loss: 0.3563 - accuracy: 0.9441
# Epoch 41: val_accuracy did not improve from 0.92708
# 14/14 [==============================] - 18s 1s/step - loss: 0.3563 - accuracy: 0.9441 - val_loss: 0.4207 - val_accuracy: 0.9219 - lr: 1.2500e-05
# Epoch 42/100
# 14/14 [==============================] - ETA: 0s - loss: 0.3686 - accuracy: 0.9418
# Epoch 42: val_accuracy did not improve from 0.92708
# 14/14 [==============================] - 19s 1s/step - loss: 0.3686 - accuracy: 0.9418 - val_loss: 0.4182 - val_accuracy: 0.8958 - lr: 1.2500e-05
# Epoch 43/100
# 14/14 [==============================] - ETA: 0s - loss: 0.3654 - accuracy: 0.9306
# Epoch 43: val_accuracy did not improve from 0.92708
# 14/14 [==============================] - 17s 1s/step - loss: 0.3654 - accuracy: 0.9306 - val_loss: 0.4247 - val_accuracy: 0.8958 - lr: 1.2500e-05
# Epoch 44/100
# 14/14 [==============================] - ETA: 0s - loss: 0.3314 - accuracy: 0.9463
# Epoch 44: val_accuracy did not improve from 0.92708
# 14/14 [==============================] - 18s 1s/step - loss: 0.3314 - accuracy: 0.9463 - val_loss: 0.4241 - val_accuracy: 0.8958 - lr: 6.2500e-06
# Epoch 45/100
# 14/14 [==============================] - ETA: 0s - loss: 0.3410 - accuracy: 0.9485
# Epoch 45: val_accuracy did not improve from 0.92708
# 14/14 [==============================] - 18s 1s/step - loss: 0.3410 - accuracy: 0.9485 - val_loss: 0.4216 - val_accuracy: 0.9010 - lr: 3.1250e-06
# Epoch 46/100
# 14/14 [==============================] - ETA: 0s - loss: 0.3327 - accuracy: 0.9508
# Epoch 46: val_accuracy did not improve from 0.92708
# 14/14 [==============================] - 17s 1s/step - loss: 0.3327 - accuracy: 0.9508 - val_loss: 0.4192 - val_accuracy: 0.9010 - lr: 1.5625e-06
# Epoch 47/100
# 14/14 [==============================] - ETA: 0s - loss: 0.3171 - accuracy: 0.9553
# Epoch 47: val_accuracy did not improve from 0.92708
# 14/14 [==============================] - 19s 1s/step - loss: 0.3171 - accuracy: 0.9553 - val_loss: 0.4176 - val_accuracy: 0.9010 - lr: 7.8125e-07
# Epoch 48/100
# 14/14 [==============================] - ETA: 0s - loss: 0.3366 - accuracy: 0.9575
# Epoch 48: val_accuracy did not improve from 0.92708
# 14/14 [==============================] - 19s 1s/step - loss: 0.3366 - accuracy: 0.9575 - val_loss: 0.4156 - val_accuracy: 0.8906 - lr: 7.8125e-07
# Epoch 49/100
# 14/14 [==============================] - ETA: 0s - loss: 0.3392 - accuracy: 0.9418
# Epoch 49: val_accuracy did not improve from 0.92708
# 14/14 [==============================] - 19s 1s/step - loss: 0.3392 - accuracy: 0.9418 - val_loss: 0.4141 - val_accuracy: 0.8958 - lr: 7.8125e-07
# Epoch 50/100
# 14/14 [==============================] - ETA: 0s - loss: 0.3420 - accuracy: 0.9396
# Epoch 50: val_accuracy did not improve from 0.92708
# 14/14 [==============================] - 19s 1s/step - loss: 0.3420 - accuracy: 0.9396 - val_loss: 0.4133 - val_accuracy: 0.8958 - lr: 7.8125e-07
# Epoch 51/100
# 14/14 [==============================] - ETA: 0s - loss: 0.3356 - accuracy: 0.9508
# Epoch 51: val_accuracy did not improve from 0.92708
# 14/14 [==============================] - 19s 1s/step - loss: 0.3356 - accuracy: 0.9508 - val_loss: 0.4119 - val_accuracy: 0.8958 - lr: 7.8125e-07
# Epoch 52/100
# 14/14 [==============================] - ETA: 0s - loss: 0.3268 - accuracy: 0.9575
# Epoch 52: val_accuracy did not improve from 0.92708
# 14/14 [==============================] - 19s 1s/step - loss: 0.3268 - accuracy: 0.9575 - val_loss: 0.4103 - val_accuracy: 0.8958 - lr: 7.8125e-07
# Epoch 53/100
# 14/14 [==============================] - ETA: 0s - loss: 0.3273 - accuracy: 0.9575
# Epoch 53: val_accuracy did not improve from 0.92708
# 14/14 [==============================] - 18s 1s/step - loss: 0.3273 - accuracy: 0.9575 - val_loss: 0.4091 - val_accuracy: 0.8958 - lr: 7.8125e-07
# Epoch 54/100
# 14/14 [==============================] - ETA: 0s - loss: 0.3324 - accuracy: 0.9597
# Epoch 54: val_accuracy did not improve from 0.92708
# 14/14 [==============================] - 19s 1s/step - loss: 0.3324 - accuracy: 0.9597 - val_loss: 0.4081 - val_accuracy: 0.8958 - lr: 7.8125e-07
# Epoch 55/100
# 14/14 [==============================] - ETA: 0s - loss: 0.3335 - accuracy: 0.9553
# Epoch 55: val_accuracy did not improve from 0.92708
# 14/14 [==============================] - 19s 1s/step - loss: 0.3335 - accuracy: 0.9553 - val_loss: 0.4073 - val_accuracy: 0.8958 - lr: 7.8125e-07
# Epoch 56/100
# 14/14 [==============================] - ETA: 0s - loss: 0.3373 - accuracy: 0.9508
# Epoch 56: val_accuracy did not improve from 0.92708
# 14/14 [==============================] - 19s 1s/step - loss: 0.3373 - accuracy: 0.9508 - val_loss: 0.4071 - val_accuracy: 0.8958 - lr: 7.8125e-07
# Epoch 57/100
# 14/14 [==============================] - ETA: 0s - loss: 0.3243 - accuracy: 0.9530
# Epoch 57: val_accuracy did not improve from 0.92708
# 14/14 [==============================] - 19s 1s/step - loss: 0.3243 - accuracy: 0.9530 - val_loss: 0.4061 - val_accuracy: 0.8958 - lr: 7.8125e-07
# Epoch 58/100
# 14/14 [==============================] - ETA: 0s - loss: 0.3304 - accuracy: 0.9553
# Epoch 58: val_accuracy did not improve from 0.92708
# 14/14 [==============================] - 19s 1s/step - loss: 0.3304 - accuracy: 0.9553 - val_loss: 0.4058 - val_accuracy: 0.8958 - lr: 7.8125e-07
# Epoch 59/100
# 14/14 [==============================] - ETA: 0s - loss: 0.3240 - accuracy: 0.9530
# Epoch 59: val_accuracy did not improve from 0.92708
# 14/14 [==============================] - 19s 1s/step - loss: 0.3240 - accuracy: 0.9530 - val_loss: 0.4052 - val_accuracy: 0.9010 - lr: 7.8125e-07
# Epoch 60/100
# 14/14 [==============================] - ETA: 0s - loss: 0.3221 - accuracy: 0.9530
# Epoch 60: val_accuracy did not improve from 0.92708
# 14/14 [==============================] - 19s 1s/step - loss: 0.3221 - accuracy: 0.9530 - val_loss: 0.4048 - val_accuracy: 0.9010 - lr: 7.8125e-07
# Epoch 61/100
# 14/14 [==============================] - ETA: 0s - loss: 0.3356 - accuracy: 0.9441
# Epoch 61: val_accuracy did not improve from 0.92708
# 14/14 [==============================] - 18s 1s/step - loss: 0.3356 - accuracy: 0.9441 - val_loss: 0.4046 - val_accuracy: 0.9010 - lr: 7.8125e-07
# Epoch 62/100
# 14/14 [==============================] - ETA: 0s - loss: 0.3340 - accuracy: 0.9485
# Epoch 62: val_accuracy did not improve from 0.92708
# 14/14 [==============================] - 19s 1s/step - loss: 0.3340 - accuracy: 0.9485 - val_loss: 0.4039 - val_accuracy: 0.9010 - lr: 7.8125e-07
# Epoch 63/100
# 14/14 [==============================] - ETA: 0s - loss: 0.3378 - accuracy: 0.9441
# Epoch 63: val_accuracy did not improve from 0.92708
# 14/14 [==============================] - 18s 1s/step - loss: 0.3378 - accuracy: 0.9441 - val_loss: 0.4035 - val_accuracy: 0.9010 - lr: 7.8125e-07
# Epoch 64/100
# 14/14 [==============================] - ETA: 0s - loss: 0.3332 - accuracy: 0.9530
# Epoch 64: val_accuracy did not improve from 0.92708
# 14/14 [==============================] - 19s 1s/step - loss: 0.3332 - accuracy: 0.9530 - val_loss: 0.4031 - val_accuracy: 0.9010 - lr: 7.8125e-07
# Epoch 65/100
# 14/14 [==============================] - ETA: 0s - loss: 0.3157 - accuracy: 0.9642
# Epoch 65: val_accuracy did not improve from 0.92708
# 14/14 [==============================] - 18s 1s/step - loss: 0.3157 - accuracy: 0.9642 - val_loss: 0.4024 - val_accuracy: 0.9010 - lr: 7.8125e-07
# Epoch 66/100
# 14/14 [==============================] - ETA: 0s - loss: 0.3245 - accuracy: 0.9553
# Epoch 66: val_accuracy did not improve from 0.92708
# 14/14 [==============================] - 17s 1s/step - loss: 0.3245 - accuracy: 0.9553 - val_loss: 0.4026 - val_accuracy: 0.9010 - lr: 7.8125e-07
# Epoch 67/100
# 14/14 [==============================] - ETA: 0s - loss: 0.3229 - accuracy: 0.9463
# Epoch 67: val_accuracy did not improve from 0.92708
# 14/14 [==============================] - 18s 1s/step - loss: 0.3229 - accuracy: 0.9463 - val_loss: 0.4027 - val_accuracy: 0.9010 - lr: 3.9062e-07
# Epoch 68/100
# 14/14 [==============================] - ETA: 0s - loss: 0.3278 - accuracy: 0.9530
# Epoch 68: val_accuracy did not improve from 0.92708
# 14/14 [==============================] - 19s 1s/step - loss: 0.3278 - accuracy: 0.9530 - val_loss: 0.4024 - val_accuracy: 0.9010 - lr: 1.9531e-07
# Epoch 69/100
# 14/14 [==============================] - ETA: 0s - loss: 0.3348 - accuracy: 0.9597
# Epoch 69: val_accuracy did not improve from 0.92708
# 14/14 [==============================] - 19s 1s/step - loss: 0.3348 - accuracy: 0.9597 - val_loss: 0.4021 - val_accuracy: 0.9010 - lr: 9.7656e-08
# Epoch 70/100
# 14/14 [==============================] - ETA: 0s - loss: 0.3222 - accuracy: 0.9597
# Epoch 70: val_accuracy did not improve from 0.92708
# 14/14 [==============================] - 18s 1s/step - loss: 0.3222 - accuracy: 0.9597 - val_loss: 0.4019 - val_accuracy: 0.9010 - lr: 9.7656e-08
# Epoch 71/100
# 14/14 [==============================] - ETA: 0s - loss: 0.3309 - accuracy: 0.9530
# Epoch 71: val_accuracy did not improve from 0.92708
# 14/14 [==============================] - 19s 1s/step - loss: 0.3309 - accuracy: 0.9530 - val_loss: 0.4019 - val_accuracy: 0.9010 - lr: 9.7656e-08
# Epoch 72/100
# 14/14 [==============================] - ETA: 0s - loss: 0.3269 - accuracy: 0.9530
# Epoch 72: val_accuracy did not improve from 0.92708
# 14/14 [==============================] - 18s 1s/step - loss: 0.3269 - accuracy: 0.9530 - val_loss: 0.4018 - val_accuracy: 0.9010 - lr: 4.8828e-08
# Epoch 73/100
# 14/14 [==============================] - ETA: 0s - loss: 0.3550 - accuracy: 0.9485
# Epoch 73: val_accuracy did not improve from 0.92708
# 14/14 [==============================] - 19s 1s/step - loss: 0.3550 - accuracy: 0.9485 - val_loss: 0.4012 - val_accuracy: 0.9010 - lr: 4.8828e-08
# Epoch 74/100
# 14/14 [==============================] - ETA: 0s - loss: 0.3224 - accuracy: 0.9485
# Epoch 74: val_accuracy did not improve from 0.92708
# 14/14 [==============================] - 19s 1s/step - loss: 0.3224 - accuracy: 0.9485 - val_loss: 0.4011 - val_accuracy: 0.9010 - lr: 4.8828e-08
# Epoch 75/100
# 14/14 [==============================] - ETA: 0s - loss: 0.3135 - accuracy: 0.9597
# Epoch 75: val_accuracy did not improve from 0.92708
# 14/14 [==============================] - 18s 1s/step - loss: 0.3135 - accuracy: 0.9597 - val_loss: 0.4011 - val_accuracy: 0.9010 - lr: 2.4414e-08
# Epoch 76/100
# 14/14 [==============================] - ETA: 0s - loss: 0.3262 - accuracy: 0.9418
# Epoch 76: val_accuracy did not improve from 0.92708
# 14/14 [==============================] - 18s 1s/step - loss: 0.3262 - accuracy: 0.9418 - val_loss: 0.4012 - val_accuracy: 0.9010 - lr: 1.2207e-08
# Epoch 77/100
# 14/14 [==============================] - ETA: 0s - loss: 0.3088 - accuracy: 0.9508
# Epoch 77: val_accuracy did not improve from 0.92708
# 14/14 [==============================] - 18s 1s/step - loss: 0.3088 - accuracy: 0.9508 - val_loss: 0.4013 - val_accuracy: 0.9010 - lr: 6.1035e-09
# Epoch 78/100
# 14/14 [==============================] - ETA: 0s - loss: 0.3149 - accuracy: 0.9553
# Epoch 78: val_accuracy did not improve from 0.92708
# 14/14 [==============================] - 17s 1s/step - loss: 0.3149 - accuracy: 0.9553 - val_loss: 0.4012 - val_accuracy: 0.9010 - lr: 3.0518e-09
# Epoch 79/100
# 14/14 [==============================] - ETA: 0s - loss: 0.3345 - accuracy: 0.9508
# Epoch 79: val_accuracy did not improve from 0.92708
# 14/14 [==============================] - 17s 1s/step - loss: 0.3345 - accuracy: 0.9508 - val_loss: 0.4011 - val_accuracy: 0.9010 - lr: 1.5259e-09
# Epoch 80/100
# 14/14 [==============================] - ETA: 0s - loss: 0.3285 - accuracy: 0.9463
# Epoch 80: val_accuracy did not improve from 0.92708
# 14/14 [==============================] - 18s 1s/step - loss: 0.3285 - accuracy: 0.9463 - val_loss: 0.4011 - val_accuracy: 0.9010 - lr: 7.6294e-10
# Epoch 81/100
# 14/14 [==============================] - ETA: 0s - loss: 0.3266 - accuracy: 0.9396
# Epoch 81: val_accuracy did not improve from 0.92708
# 14/14 [==============================] - 19s 1s/step - loss: 0.3266 - accuracy: 0.9396 - val_loss: 0.4011 - val_accuracy: 0.9010 - lr: 3.8147e-10
# Epoch 82/100
# 14/14 [==============================] - ETA: 0s - loss: 0.3462 - accuracy: 0.9485
# Epoch 82: val_accuracy did not improve from 0.92708
# 14/14 [==============================] - 18s 1s/step - loss: 0.3462 - accuracy: 0.9485 - val_loss: 0.4009 - val_accuracy: 0.9010 - lr: 1.9073e-10
# Epoch 83/100
# 14/14 [==============================] - ETA: 0s - loss: 0.3151 - accuracy: 0.9553
# Epoch 83: val_accuracy did not improve from 0.92708
# 14/14 [==============================] - 18s 1s/step - loss: 0.3151 - accuracy: 0.9553 - val_loss: 0.4009 - val_accuracy: 0.9010 - lr: 1.9073e-10
# Epoch 84/100
# 14/14 [==============================] - ETA: 0s - loss: 0.3467 - accuracy: 0.9329
# Epoch 84: val_accuracy did not improve from 0.92708
# 14/14 [==============================] - 19s 1s/step - loss: 0.3467 - accuracy: 0.9329 - val_loss: 0.4008 - val_accuracy: 0.9010 - lr: 1.0000e-10
# Epoch 85/100
# 14/14 [==============================] - ETA: 0s - loss: 0.3403 - accuracy: 0.9485
# Epoch 85: val_accuracy did not improve from 0.92708
# 14/14 [==============================] - 19s 1s/step - loss: 0.3403 - accuracy: 0.9485 - val_loss: 0.4007 - val_accuracy: 0.9010 - lr: 1.0000e-10
# Epoch 86/100
# 14/14 [==============================] - ETA: 0s - loss: 0.3224 - accuracy: 0.9508
# Epoch 86: val_accuracy did not improve from 0.92708
# 14/14 [==============================] - 18s 1s/step - loss: 0.3224 - accuracy: 0.9508 - val_loss: 0.4010 - val_accuracy: 0.9010 - lr: 1.0000e-10
# Epoch 87/100
# 14/14 [==============================] - ETA: 0s - loss: 0.3341 - accuracy: 0.9553
# Epoch 87: val_accuracy did not improve from 0.92708
# 14/14 [==============================] - 17s 1s/step - loss: 0.3341 - accuracy: 0.9553 - val_loss: 0.4012 - val_accuracy: 0.9010 - lr: 1.0000e-10
# Epoch 88/100
# 14/14 [==============================] - ETA: 0s - loss: 0.3288 - accuracy: 0.9485
# Epoch 88: val_accuracy did not improve from 0.92708
# 14/14 [==============================] - 17s 1s/step - loss: 0.3288 - accuracy: 0.9485 - val_loss: 0.4010 - val_accuracy: 0.9010 - lr: 1.0000e-10
# Epoch 89/100
# 14/14 [==============================] - ETA: 0s - loss: 0.3203 - accuracy: 0.9664
# Epoch 89: val_accuracy did not improve from 0.92708
# 14/14 [==============================] - 18s 1s/step - loss: 0.3203 - accuracy: 0.9664 - val_loss: 0.4012 - val_accuracy: 0.9010 - lr: 1.0000e-10
# Epoch 90/100
# 14/14 [==============================] - ETA: 0s - loss: 0.3336 - accuracy: 0.9485
# Epoch 90: val_accuracy did not improve from 0.92708
# 14/14 [==============================] - 18s 1s/step - loss: 0.3336 - accuracy: 0.9485 - val_loss: 0.4011 - val_accuracy: 0.9010 - lr: 1.0000e-10
# Epoch 91/100
# 14/14 [==============================] - ETA: 0s - loss: 0.3492 - accuracy: 0.9351
# Epoch 91: val_accuracy did not improve from 0.92708
# 14/14 [==============================] - 18s 1s/step - loss: 0.3492 - accuracy: 0.9351 - val_loss: 0.4012 - val_accuracy: 0.9010 - lr: 1.0000e-10
# Epoch 92/100
# 14/14 [==============================] - ETA: 0s - loss: 0.3330 - accuracy: 0.9441
# Epoch 92: val_accuracy did not improve from 0.92708
# 14/14 [==============================] - 18s 1s/step - loss: 0.3330 - accuracy: 0.9441 - val_loss: 0.4013 - val_accuracy: 0.9010 - lr: 1.0000e-10
# Epoch 93/100
# 14/14 [==============================] - ETA: 0s - loss: 0.3291 - accuracy: 0.9441
# Epoch 93: val_accuracy did not improve from 0.92708
# 14/14 [==============================] - 18s 1s/step - loss: 0.3291 - accuracy: 0.9441 - val_loss: 0.4014 - val_accuracy: 0.9010 - lr: 1.0000e-10
# Epoch 94/100
# 14/14 [==============================] - ETA: 0s - loss: 0.3092 - accuracy: 0.9687
# Epoch 94: val_accuracy did not improve from 0.92708
# 14/14 [==============================] - 18s 1s/step - loss: 0.3092 - accuracy: 0.9687 - val_loss: 0.4016 - val_accuracy: 0.9010 - lr: 1.0000e-10
# Epoch 95/100
# 14/14 [==============================] - ETA: 0s - loss: 0.3243 - accuracy: 0.9485
# Epoch 95: val_accuracy did not improve from 0.92708
# 14/14 [==============================] - 19s 1s/step - loss: 0.3243 - accuracy: 0.9485 - val_loss: 0.4014 - val_accuracy: 0.9010 - lr: 1.0000e-10

# %% [markdown]
# ## Vanila LSTM

# %%
from tensorflow.keras.applications import InceptionV3
from tensorflow.keras.layers import Input, TimeDistributed, Flatten, LSTM, BatchNormalization, Dropout, Dense, Conv2D
from tensorflow.keras.models import Model
from tensorflow.keras.optimizers import Adam


base_model = InceptionV3(weights='imagenet', include_top=False, input_shape=(IMAGE_SIZE[0], IMAGE_SIZE[1], 3))
base_model.trainable = False

# Define LSTM model
inputs = Input(shape=(SEQUENCE_LENGTH,) + IMAGE_SIZE + (3,))
x = TimeDistributed(base_model)(inputs)
x = TimeDistributed(Flatten())(x)  # Flatten the output of InceptionV3
x = LSTM(256, return_sequences=False)(x)  # Set return_sequences to False
x = BatchNormalization()(x)  # Batch normalization
x = Dropout(0.5)(x)  # Dropout
outputs = Dense(NUM_CLASSES, activation='softmax')(x)
model = Model(inputs, outputs)
opt = Adam(learning_rate=0.0001)
model.compile(loss='categorical_crossentropy', optimizer=opt, metrics=['accuracy'])

# %%
from keras.callbacks import ModelCheckpoint, EarlyStopping, ReduceLROnPlateau
# Define callbacks
checkpoint = ModelCheckpoint(root_folder+"/best_model.h5", monitor='val_accuracy', verbose=1, save_best_only=True, mode='max')
early_stopping = EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)
reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=1, min_lr=0.0000000001)

# Training
history = model.fit(X_train, y_train, epochs=100, batch_size=32, validation_data=(X_test, y_test), callbacks=[checkpoint, early_stopping, reduce_lr])
# Out:
# Epoch 1/100
# 14/14 [==============================] - ETA: 0s - loss: 1.6061 - accuracy: 0.4072
# Epoch 1: val_accuracy improved from -inf to 0.09896, saving model to /content/drive/MyDrive/dogs_dataset/best_model.h5
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# 14/14 [==============================] - 43s 3s/step - loss: 1.6061 - accuracy: 0.4072 - val_loss: 1.7257 - val_accuracy: 0.0990 - lr: 1.0000e-04
# Epoch 2/100
# 14/14 [==============================] - ETA: 0s - loss: 1.2525 - accuracy: 0.5101
# Epoch 2: val_accuracy improved from 0.09896 to 0.21354, saving model to /content/drive/MyDrive/dogs_dataset/best_model.h5
# 14/14 [==============================] - 40s 3s/step - loss: 1.2525 - accuracy: 0.5101 - val_loss: 1.5998 - val_accuracy: 0.2135 - lr: 1.0000e-04
# Epoch 3/100
# 14/14 [==============================] - ETA: 0s - loss: 1.1918 - accuracy: 0.5347
# Epoch 3: val_accuracy improved from 0.21354 to 0.38021, saving model to /content/drive/MyDrive/dogs_dataset/best_model.h5
# 14/14 [==============================] - 38s 3s/step - loss: 1.1918 - accuracy: 0.5347 - val_loss: 1.3953 - val_accuracy: 0.3802 - lr: 1.0000e-04
# Epoch 4/100
# 14/14 [==============================] - ETA: 0s - loss: 1.1207 - accuracy: 0.5996
# Epoch 4: val_accuracy improved from 0.38021 to 0.44271, saving model to /content/drive/MyDrive/dogs_dataset/best_model.h5
# 14/14 [==============================] - 25s 2s/step - loss: 1.1207 - accuracy: 0.5996 - val_loss: 1.3243 - val_accuracy: 0.4427 - lr: 1.0000e-04
# Epoch 5/100
# 14/14 [==============================] - ETA: 0s - loss: 1.0894 - accuracy: 0.6107
# Epoch 5: val_accuracy did not improve from 0.44271
# 14/14 [==============================] - 15s 1s/step - loss: 1.0894 - accuracy: 0.6107 - val_loss: 1.4151 - val_accuracy: 0.2708 - lr: 1.0000e-04
# Epoch 6/100
# 14/14 [==============================] - ETA: 0s - loss: 1.0064 - accuracy: 0.6622
# Epoch 6: val_accuracy did not improve from 0.44271
# 14/14 [==============================] - 16s 1s/step - loss: 1.0064 - accuracy: 0.6622 - val_loss: 1.4198 - val_accuracy: 0.2240 - lr: 5.0000e-05
# Epoch 7/100
# 14/14 [==============================] - ETA: 0s - loss: 0.9807 - accuracy: 0.6957
# Epoch 7: val_accuracy did not improve from 0.44271
# 14/14 [==============================] - 15s 1s/step - loss: 0.9807 - accuracy: 0.6957 - val_loss: 1.3698 - val_accuracy: 0.2812 - lr: 2.5000e-05
# Epoch 8/100
# 14/14 [==============================] - ETA: 0s - loss: 0.9452 - accuracy: 0.7114
# Epoch 8: val_accuracy did not improve from 0.44271
# 14/14 [==============================] - 15s 1s/step - loss: 0.9452 - accuracy: 0.7114 - val_loss: 1.2900 - val_accuracy: 0.4219 - lr: 1.2500e-05
# Epoch 9/100
# 14/14 [==============================] - ETA: 0s - loss: 0.9255 - accuracy: 0.7472
# Epoch 9: val_accuracy improved from 0.44271 to 0.53125, saving model to /content/drive/MyDrive/dogs_dataset/best_model.h5
# 14/14 [==============================] - 53s 4s/step - loss: 0.9255 - accuracy: 0.7472 - val_loss: 1.2402 - val_accuracy: 0.5312 - lr: 1.2500e-05
# Epoch 10/100
# 14/14 [==============================] - ETA: 0s - loss: 0.9043 - accuracy: 0.7315
# Epoch 10: val_accuracy improved from 0.53125 to 0.58854, saving model to /content/drive/MyDrive/dogs_dataset/best_model.h5
# 14/14 [==============================] - 39s 3s/step - loss: 0.9043 - accuracy: 0.7315 - val_loss: 1.2020 - val_accuracy: 0.5885 - lr: 1.2500e-05
# Epoch 11/100
# 14/14 [==============================] - ETA: 0s - loss: 0.9032 - accuracy: 0.7136
# Epoch 11: val_accuracy improved from 0.58854 to 0.69271, saving model to /content/drive/MyDrive/dogs_dataset/best_model.h5
# 14/14 [==============================] - 26s 2s/step - loss: 0.9032 - accuracy: 0.7136 - val_loss: 1.1594 - val_accuracy: 0.6927 - lr: 1.2500e-05
# Epoch 12/100
# 14/14 [==============================] - ETA: 0s - loss: 0.8837 - accuracy: 0.7584
# Epoch 12: val_accuracy improved from 0.69271 to 0.75000, saving model to /content/drive/MyDrive/dogs_dataset/best_model.h5
# 14/14 [==============================] - 31s 2s/step - loss: 0.8837 - accuracy: 0.7584 - val_loss: 1.1341 - val_accuracy: 0.7500 - lr: 1.2500e-05
# Epoch 13/100
# 14/14 [==============================] - ETA: 0s - loss: 0.8883 - accuracy: 0.7405
# Epoch 13: val_accuracy improved from 0.75000 to 0.78646, saving model to /content/drive/MyDrive/dogs_dataset/best_model.h5
# 14/14 [==============================] - 31s 2s/step - loss: 0.8883 - accuracy: 0.7405 - val_loss: 1.0984 - val_accuracy: 0.7865 - lr: 1.2500e-05
# Epoch 14/100
# 14/14 [==============================] - ETA: 0s - loss: 0.8578 - accuracy: 0.7427
# Epoch 14: val_accuracy improved from 0.78646 to 0.79167, saving model to /content/drive/MyDrive/dogs_dataset/best_model.h5
# 14/14 [==============================] - 33s 2s/step - loss: 0.8578 - accuracy: 0.7427 - val_loss: 1.0425 - val_accuracy: 0.7917 - lr: 1.2500e-05
# Epoch 15/100
# 14/14 [==============================] - ETA: 0s - loss: 0.8698 - accuracy: 0.7584
# Epoch 15: val_accuracy did not improve from 0.79167
# 14/14 [==============================] - 16s 1s/step - loss: 0.8698 - accuracy: 0.7584 - val_loss: 1.0094 - val_accuracy: 0.7917 - lr: 1.2500e-05
# Epoch 16/100
# 14/14 [==============================] - ETA: 0s - loss: 0.8323 - accuracy: 0.7763
# Epoch 16: val_accuracy improved from 0.79167 to 0.80208, saving model to /content/drive/MyDrive/dogs_dataset/best_model.h5

# %% [markdown]
# # Evaluation

# %%
from sklearn.metrics import roc_auc_score, roc_curve
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix
import matplotlib.pyplot as plt
import seaborn as sns

def plot_training_history(history, main_title):
    plt.figure(figsize=(12, 6))

    # Plot model loss
    plt.subplot(1, 2, 1)
    plt.plot(history.history['loss'])
    plt.plot(history.history['val_loss'])
    plt.title(main_title + ' - Model Loss')
    plt.ylabel('Loss')
    plt.xlabel('Epoch')
    plt.legend(['Train', 'Validation'], loc='upper left')

    # Plot model accuracy
    plt.subplot(1, 2, 2)
    plt.plot(history.history['accuracy'])
    plt.plot(history.history['val_accuracy'])
    plt.title(main_title + ' - Model Accuracy')
    plt.ylabel('Accuracy')
    plt.xlabel('Epoch')
    plt.legend(['Train', 'Validation'], loc='upper left')

    plt.show()

def plot_confusion_matrix(X, y, model, label_encoder):
    y_pred = model.predict(X)
    y_true = label_encoder.inverse_transform(np.argmax(y, axis=1))
    y_pred = label_encoder.inverse_transform(np.argmax(y_pred, axis=1))
    conf_matrix = confusion_matrix(y_true, y_pred)

    plt.figure(figsize=(10, 8))
    sns.heatmap(conf_matrix, annot=True, fmt="d", cmap="Blues", xticklabels=label_encoder.classes_, yticklabels=label_encoder.classes_)
    plt.xlabel('Predicted Labels')
    plt.ylabel('True Labels')
    plt.title('Confusion Matrix')
    plt.show()

def plot_roc_auc_curve(model, X, y_true):
    # Predict probabilities for each class
    y_prob = model.predict(X)
    y_true = label_encoder.inverse_transform(np.argmax(y_true, axis=1))
    y_prob = label_encoder.inverse_transform(np.argmax(y_prob, axis=1))

    # Compute ROC AUC score for each class
    auc_scores = []
    for i in range(len(label_encoder.classes_)):
        auc_score = roc_auc_score(y_true[:, i], y_prob[:, i])
        auc_scores.append(auc_score)

    # Plot ROC AUC curve for each class
    plt.figure(figsize=(8, 6))
    for i in range(len(label_encoder.classes_)):
        fpr, tpr, _ = roc_curve(y_true[:, i], y_prob[:, i])
        plt.plot(fpr, tpr, label=label_encoder.classes_[i] + ' (AUC = {:.2f})'.format(auc_scores[i]))

    plt.plot([0, 1], [0, 1], 'k--', label='Random Guessing')
    plt.xlabel('False Positive Rate')
    plt.ylabel('True Positive Rate')
    plt.title('ROC AUC Curve')
    plt.legend(loc='lower right')
    plt.grid(True)
    plt.show()


from sklearn.preprocessing import label_binarize

def plot_roc_auc_curve(model, X, y_true, class_names, main_title='ROC Curve'):
    """
    Plots the ROC curve for multi-class classification and calculates the AUC score for each class.

    Parameters:
    - model: trained model used for predictions.
    - X: array-like, feature data.
    - y_true: array-like, true labels.
    - class_names: list, names of the classes.
    - main_title: str, title of the plot.

    Returns:
    - None
    """
    # Predict probabilities
    y_pred_prob = model.predict(X)

    # Binarize the true labels
    y_true_binarized = label_binarize(y_true, classes=range(len(class_names)))

    # Plot settings
    plt.figure(figsize=(12, 8))
    sns.set(style='whitegrid')

    # Plot ROC curve for each class
    for i, class_name in enumerate(class_names):
        fpr, tpr, _ = roc_curve(y_true_binarized[:, i], y_pred_prob[:, i])
        roc_auc = roc_auc_score(y_true_binarized[:, i], y_pred_prob[:, i])

        plt.plot(fpr, tpr, lw=2, label=f'{class_name} (AUC = {roc_auc:.2f})')

    plt.plot([0, 1], [0, 1], color='gray', linestyle='--')

    plt.xlim([0.0, 1.0])
    plt.ylim([0.0, 1.05])
    plt.xlabel('False Positive Rate')
    plt.ylabel('True Positive Rate')
    plt.title(main_title)
    plt.legend(loc='lower right')

    plt.show()

# %% [markdown]
# ## Stacked LSTM

# %% [markdown]
# ### Loss accuracy plot

# %%
plot_training_history(history_stack, 'Stacked LSTM')

# %% [markdown]
# ### Confusion Matrix

# %%
def plot_confusion_matrix(X, y, model, class_dict):
    """
    Plots the confusion matrix for the given model and data.

    Parameters:
    - X: array-like, feature data.
    - y: array-like, true labels (one-hot encoded).
    - model: trained model used for predictions.
    - class_dict: dictionary mapping class indices to class names.

    Returns:
    - None
    """
    y_pred = model.predict(X)
    y_true = np.argmax(y, axis=1)
    y_pred = np.argmax(y_pred, axis=1)

    # Map numeric labels to class names
    class_names = [class_dict[i] for i in range(len(class_dict))]

    conf_matrix = confusion_matrix(y_true, y_pred)

    plt.figure(figsize=(10, 8))
    sns.heatmap(conf_matrix, annot=True, fmt="d", cmap="Blues", xticklabels=class_names, yticklabels=class_names)
    plt.xlabel('Predicted Labels')
    plt.ylabel('True Labels')
    plt.title('Confusion Matrix')
    plt.show()

# %%
from tensorflow.keras.models import load_model
checkpoint_path = root_folder + '/best_stackmodel.h5'

# Load the model from the checkpoint
stack_model = load_model(checkpoint_path)

# %%
from sklearn.metrics import confusion_matrix
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
plot_confusion_matrix(X, y_one_hot, stack_model, class_dict)
# Out:
# 20/20 [==============================] - 14s 721ms/step

# %%
plot_confusion_matrix(X_test, y_test, stack_model, class_dict)
# Out:
# 6/6 [==============================] - 4s 748ms/step

# %%
plot_confusion_matrix(X, y_one_hot, stack_model, label_encoder)
# Out:
# 20/20 [==============================] - 16s 648ms/step

# %%
plot_confusion_matrix(X_test, y_test, stack_model, label_encoder)
# Out:
# 6/6 [==============================] - 4s 695ms/step

# %% [markdown]
# ### ROC Curve

# %%
def plot_roc_auc_curve(model, X, y, class_dict, title):
    """
    Plots the ROC AUC curve for the given model and data.

    Parameters:
    - model: trained model used for predictions.
    - X: array-like, feature data.
    - y: array-like, true labels (one-hot encoded).
    - class_dict: dictionary mapping class indices to class names.

    Returns:
    - None
    """
    y_pred = model.predict(X)
    n_classes = y.shape[1]

    # Compute ROC curve and ROC AUC for each class
    fpr = dict()
    tpr = dict()
    roc_auc = dict()
    for i in range(n_classes):
        fpr[i], tpr[i], _ = roc_curve(y[:, i], y_pred[:, i])
        roc_auc[i] = roc_auc_score(y[:, i], y_pred[:, i])

    # Plot all ROC curves
    plt.figure(figsize=(10, 8))
    colors = ['aqua', 'darkorange', 'cornflowerblue', 'green', 'red']
    for i, color in zip(range(n_classes), colors):
        plt.plot(fpr[i], tpr[i], color=color, lw=2,
                 label=f'ROC curve of class {class_dict[i]} (area = {roc_auc[i]:0.2f})')

    plt.plot([0, 1], [0, 1], 'k--', lw=2)
    plt.xlim([0.0, 1.0])
    plt.ylim([0.0, 1.05])
    plt.xlabel('False Positive Rate')
    plt.ylabel('True Positive Rate')
    plt.title(title)
    plt.legend(loc="lower right")
    plt.show()

# %%
class_names = ['Class 1', 'Class 2', 'Class 3', 'Class 4', 'Class 5']

# %%
plot_roc_auc_curve(stack_model, X, y_one_hot, class_dict, 'Stacked LSTM ROC Curve')
# Out:
# 20/20 [==============================] - 14s 703ms/step

# %%
from sklearn.metrics import classification_report
def display_classification_report(model, X, y_true, class_dict):
    """
    Displays the classification report for multi-class classification.

    Parameters:
    - model: trained model used for predictions.
    - X: array-like, feature data.
    - y_true: array-like, true labels (one-hot encoded).
    - class_dict: dictionary mapping class indices to class names.

    Returns:
    - None
    """
    # Predict class labels
    y_pred = model.predict(X)
    y_pred_classes = np.argmax(y_pred, axis=1)
    y_true_classes = np.argmax(y_true, axis=1)

    # Generate classification report
    class_names = [class_dict[i] for i in range(len(class_dict))]
    report = classification_report(y_true_classes, y_pred_classes, target_names=class_names)

    print("Classification Report:\n")
    print(report)

# %%
display_classification_report(stack_model, X, y_one_hot, class_dict)

# %%
display_classification_report(stack_model, X_test, y_test, class_dict)
# Out:
# 6/6 [==============================] - 4s 769ms/step
# Classification Report:
#
#               precision    recall  f1-score   support
#
#      walking       0.92      1.00      0.96        22
#        lying       1.00      1.00      1.00        32
#      barking       1.00      0.97      0.99        76
#      sitting       1.00      1.00      1.00        41
#     standing       0.95      0.95      0.95        21
#
#     accuracy                           0.98       192
#    macro avg       0.97      0.99      0.98       192
# weighted avg       0.99      0.98      0.98       192

# %% [markdown]
# ## Bidirectional LSTM

# %% [markdown]
# ### Loss accuracy plot

# %%
plot_training_history(history_bidirectional, 'Bidirectional LSTM')

# %% [markdown]
# ### Confusion Matrix

# %%
plot_confusion_matrix(X_test, y_test, bi_model, class_dict)
# Out:
# 6/6 [==============================] - 4s 714ms/step

# %% [markdown]
# ### ROC Curve

# %%
plot_roc_auc_curve(bi_model, X_test, y_test, class_dict, 'Bidirectional LSTM ROC Curve')
# Out:
# 6/6 [==============================] - 4s 724ms/step

# %%
display_classification_report(bi_model, X_test, y_test, class_dict)
# Out:
# 6/6 [==============================] - 4s 713ms/step
# Classification Report:
#
#               precision    recall  f1-score   support
#
#      walking       0.92      0.55      0.69        22
#        lying       0.84      1.00      0.91        32
#      barking       0.92      0.93      0.93        76
#      sitting       0.87      0.98      0.92        41
#     standing       1.00      0.86      0.92        21
#
#     accuracy                           0.90       192
#    macro avg       0.91      0.86      0.87       192
# weighted avg       0.91      0.90      0.90       192

# %% [markdown]
# ## Vanila LSTM

# %% [markdown]
# ### Loss accuracy plot

# %%
plot_training_history(history, 'Vanila LSTM')

# %% [markdown]
# ### Confusion Matrix

# %%
plot_confusion_matrix(X, y_one_hot, model, label_encoder)

# %% [markdown]
# ### ROC Curve

# %%
plot_roc_auc_curve(model, X, y_one_hot, class_dict, 'Stacked LSTM ROC Curve')
